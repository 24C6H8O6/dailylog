# %%
# !pip install markupsafe==2.0.1
# Out:
# Requirement already satisfied: markupsafe==2.0.1 in c:\users\ai\anaconda3\lib\site-packages (2.0.1)

# %%
# !pip install pycaret
# Out:
# Collecting pycaret
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# Collecting umap-learn
#   Using cached umap_learn-0.5.3-py3-none-any.whl
# Requirement already satisfied: plotly>=4.4.1 in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (5.6.0)
# Requirement already satisfied: nltk in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (3.7)
# Collecting spacy<2.4.0
#   Using cached spacy-2.3.7-cp39-cp39-win_amd64.whl (9.4 MB)
# Requirement already satisfied: pandas in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: joblib in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (1.1.0)
# Collecting cufflinks>=0.17.0
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# Requirement already satisfied: lightgbm>=2.3.1 in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (3.3.2)
# Collecting pyyaml<6.0.0
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# Requirement already satisfied: IPython in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (8.2.0)
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Collecting mlxtend>=0.17.0
#   Using cached mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
# Collecting scikit-plot
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Collecting Boruta
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# Collecting numba<0.55
#   Using cached numba-0.54.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.3.1-py2.py3-none-any.whl
# Collecting gensim<4.0.0
#   Using cached gensim-3.8.3.tar.gz (23.4 MB)
# Collecting mlflow
#   Using cached mlflow-1.27.0-py3-none-any.whl (17.9 MB)
# Collecting imbalanced-learn==0.7.0
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\AI\Anaconda3\python.exe' 'C:\Users\AI\AppData\Local\Temp\pip-standalone-pip-i7q3wms5\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\AI\AppData\Local\Temp\pip-build-env-j53d_3x3\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (595 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-63.2.0-py3-none-any.whl (1.2 MB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.30-py2.py3-none-any.whl (985 kB)
#   Collecting numpy==1.17.3
#     Using cached numpy-1.17.3.zip (6.4 MB)
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\AI\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-q4qrxtkl\\numpy_720f599b2b2846f6b396e9eff923bbde\\setup.py'"'"'; __file__='"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-q4qrxtkl\\numpy_720f599b2b2846f6b396e9eff923bbde\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\AI\AppData\Local\Temp\pip-wheel-m5953z8x'
#          cwd: C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\
#     Complete output (268 lines):
#     Running from numpy source directory.
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#     배치 파일이 아닙니다.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\AI\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\AI\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\AI\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\AI\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#       NOT AVAILABLE
#
#     C:\Users\AI\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\AI\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-q4qrxtkl\\numpy_720f599b2b2846f6b396e9eff923bbde\\setup.py'"'"'; __file__='"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-q4qrxtkl\\numpy_720f599b2b2846f6b396e9eff923bbde\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' clean --all
#          cwd: C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde
#     Complete output (10 lines):
#     Running from numpy source directory.
#
#     `setup.py clean` is not supported, use one of the following instead:
#
#       - `git clean -xdf` (cleans all files)
#       - `git clean -Xdf` (cleans all versioned files, doesn't touch
#                           files that aren't checked into the git repo)
#
#     Add `--force` to your command to use it anyway if you must (unsupported).
#
#     ----------------------------------------
#     ERROR: Failed cleaning build dir for numpy
#   Failed to build numpy
#   Installing collected packages: numpy, wheel, setuptools, scipy, Cython
#       Running setup.py install for numpy: started
#       Running setup.py install for numpy: finished with status 'error'
#       ERROR: Command errored out with exit status 1:
#        command: 'C:\Users\AI\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-q4qrxtkl\\numpy_720f599b2b2846f6b396e9eff923bbde\\setup.py'"'"'; __file__='"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-q4qrxtkl\\numpy_720f599b2b2846f6b396e9eff923bbde\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\AI\AppData\Local\Temp\pip-record-i50v5avp\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\AI\AppData\Local\Temp\pip-build-env-j53d_3x3\overlay' --compile --install-headers 'C:\Users\AI\AppData\Local\Temp\pip-build-env-j53d_3x3\overlay\Include\numpy'
#            cwd: C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\
#       Complete output (275 lines):
#       Running from numpy source directory.
# Requirement already satisfied: ipywidgets in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (7.6.5)
# Collecting kmodes>=0.10.1
#   Using cached kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Collecting pandas-profiling>=2.8.0
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Requirement already satisfied: seaborn in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (0.11.2)
# Collecting yellowbrick>=1.0.1
#   Using cached yellowbrick-1.4-py3-none-any.whl (274 kB)
# Requirement already satisfied: matplotlib in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (3.5.1)
# Collecting scipy<=1.5.4
#   Using cached scipy-1.5.4-cp39-cp39-win_amd64.whl (31.4 MB)
# Requirement already satisfied: wordcloud in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (1.8.2.2)
# Collecting pyod
#   Using cached pyod-1.0.3-py3-none-any.whl
# Collecting scikit-learn==0.23.2
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting pycaret
#   Using cached pycaret-2.3.9-py3-none-any.whl (319 kB)
#   Using cached pycaret-2.3.8-py3-none-any.whl (318 kB)
#   Using cached pycaret-2.3.7-py3-none-any.whl (318 kB)
#   Using cached pycaret-2.3.6-py3-none-any.whl (301 kB)
#   Using cached pycaret-2.3.5-py3-none-any.whl (288 kB)
# Collecting numpy==1.19.5
#   Using cached numpy-1.19.5-cp39-cp39-win_amd64.whl (13.3 MB)
# Collecting pycaret
#   Using cached pycaret-2.3.4-py3-none-any.whl (266 kB)
# Collecting numba<0.54
#   Downloading numba-0.53.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting pycaret
#   Using cached pycaret-2.3.3-py3-none-any.whl (264 kB)
#   Using cached pycaret-2.3.2-py3-none-any.whl (263 kB)
#   Using cached pycaret-2.3.1-py3-none-any.whl (261 kB)
#   Using cached pycaret-2.3.0-py3-none-any.whl (261 kB)
# Collecting imbalanced-learn>=0.7.0
#   Using cached imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# Requirement already satisfied: gensim in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (4.1.2)
# Collecting pycaret
#   Using cached pycaret-2.2.3-py3-none-any.whl (249 kB)
# Collecting catboost>=0.23.2
#   Using cached catboost-1.0.6-cp39-none-win_amd64.whl (73.9 MB)
# Collecting spacy
#   Using cached spacy-3.4.0-cp39-cp39-win_amd64.whl (11.8 MB)
# Requirement already satisfied: numpy>=1.17 in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: xgboost>=1.1.0 in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (1.6.1)
# Collecting pycaret
#   Using cached pycaret-2.2.2-py3-none-any.whl (249 kB)
# Requirement already satisfied: scikit-learn>=0.23.2 in c:\users\ai\anaconda3\lib\site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: scipy in c:\users\ai\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.7.3)
# Requirement already satisfied: six in c:\users\ai\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (1.16.0)
# Requirement already satisfied: graphviz in c:\users\ai\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret) (0.20)
# Collecting colorlover>=0.2.1
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\ai\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret) (61.2.0)
# Collecting scikit-learn>=0.23.2
#   Using cached scikit_learn-1.1.1-cp39-cp39-win_amd64.whl (7.4 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ai\anaconda3\lib\site-packages (from imbalanced-learn>=0.7.0->pycaret) (2.2.0)
# Requirement already satisfied: stack-data in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (0.1.2)
# Requirement already satisfied: traitlets>=5 in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: colorama in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (0.4.4)
# Requirement already satisfied: decorator in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (2.11.2)
# Requirement already satisfied: backcall in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret) (0.7.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret) (6.9.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret) (1.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\ai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\ai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ai\anaconda3\lib\site-packages (from jedi>=0.16->IPython->pycaret) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\ai\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ai\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ai\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ai\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret) (302)
# Requirement already satisfied: wheel in c:\users\ai\anaconda3\lib\site-packages (from lightgbm>=2.3.1->pycaret) (0.37.1)
# Requirement already satisfied: fastjsonschema in c:\users\ai\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ai\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ai\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ai\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret) (21.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ai\anaconda3\lib\site-packages (from pandas->pycaret) (2021.3)
# Requirement already satisfied: requests>=2.24.0 in c:\users\ai\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.27.1)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\ai\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (4.64.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\ai\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (2.11.3)
# Collecting markupsafe~=2.1.1
#   Using cached MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl (17 kB)
# Collecting tangled-up-in-unicode==0.2.0
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Collecting phik>=0.11.1
#   Using cached phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting pydantic>=1.8.1
#   Using cached pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\ai\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret) (6.0)
# Collecting multimethod>=1.4
#   Using cached multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: networkx>=2.4 in c:\users\ai\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (2.7.1)
# Collecting imagehash
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: Pillow in c:\users\ai\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ai\anaconda3\lib\site-packages (from plotly>=4.4.1->pycaret) (8.0.1)
# Requirement already satisfied: wcwidth in c:\users\ai\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ai\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret) (2021.10.8)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ai\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.8)
# Requirement already satisfied: prometheus-client in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.8.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ai\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ai\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ai\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ai\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.21)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\ai\anaconda3\lib\site-packages (from gensim->pycaret) (5.1.0)
# Requirement already satisfied: PyWavelets in c:\users\ai\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret) (1.3.0)
# Collecting prometheus-flask-exporter
#   Using cached prometheus_flask_exporter-0.20.2-py3-none-any.whl (18 kB)
# Requirement already satisfied: Flask in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret) (1.1.2)
# Collecting docker>=4.0.0
#   Using cached docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret) (4.11.3)
# Collecting databricks-cli>=0.8.7
#   Using cached databricks_cli-0.17.0-py3-none-any.whl
# Collecting querystring-parser
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: entrypoints in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret) (0.4)
# Collecting gitpython>=2.1.0
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Requirement already satisfied: cloudpickle in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret) (2.0.0)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret) (3.19.1)
# Requirement already satisfied: sqlalchemy>=1.4.0 in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret) (1.4.32)
# Collecting alembic
#   Using cached alembic-1.8.1-py3-none-any.whl (209 kB)
# Collecting sqlparse>=0.3.1
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Requirement already satisfied: click>=7.0 in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret) (8.0.4)
# Collecting waitress
#   Using cached waitress-2.1.2-py3-none-any.whl (57 kB)
# Collecting oauthlib>=3.1.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\ai\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (2.1.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\ai\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\ai\anaconda3\lib\site-packages (from docker>=4.0.0->mlflow->pycaret) (0.58.0)
# Collecting pywin32>=1.0
#   Using cached pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\ai\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret) (3.7.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ai\anaconda3\lib\site-packages (from sqlalchemy>=1.4.0->mlflow->pycaret) (1.1.1)
# Collecting Mako
#   Using cached Mako-1.2.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\ai\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\ai\anaconda3\lib\site-packages (from Flask->mlflow->pycaret) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.8.4)
# Requirement already satisfied: testpath in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.13)
# Requirement already satisfied: defusedxml in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (1.5.0)
# Requirement already satisfied: bleach in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ai\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\ai\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ai\anaconda3\lib\site-packages (from nltk->pycaret) (2022.3.15)
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Collecting funcy
#   Using cached funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: future in c:\users\ai\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (0.18.2)
# Requirement already satisfied: numexpr in c:\users\ai\anaconda3\lib\site-packages (from pyLDAvis->pycaret) (2.8.1)
# Requirement already satisfied: statsmodels in c:\users\ai\anaconda3\lib\site-packages (from pyod->pycaret) (0.13.2)
# Requirement already satisfied: numba>=0.51 in c:\users\ai\anaconda3\lib\site-packages (from pyod->pycaret) (0.55.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\ai\anaconda3\lib\site-packages (from numba>=0.51->pyod->pycaret) (0.38.0)
# Collecting wasabi<1.1.0,>=0.9.1
#   Using cached wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Using cached typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.6-cp39-cp39-win_amd64.whl (112 kB)
# Collecting thinc<8.2.0,>=8.1.0
#   Using cached thinc-8.1.0-cp39-cp39-win_amd64.whl (1.3 MB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.4-cp39-cp39-win_amd64.whl (450 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.7-cp39-cp39-win_amd64.whl (18 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Using cached spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp39-cp39-win_amd64.whl (36 kB)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.2-py3-none-any.whl (42 kB)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.8-cp39-cp39-win_amd64.whl (6.6 MB)
# Requirement already satisfied: asttokens in c:\users\ai\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ai\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (0.2.2)
# Requirement already satisfied: executing in c:\users\ai\anaconda3\lib\site-packages (from stack-data->IPython->pycaret) (0.8.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ai\anaconda3\lib\site-packages (from statsmodels->pyod->pycaret) (0.5.2)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.7-py3-none-any.whl
# Installing collected packages: pywin32, markupsafe, tangled-up-in-unicode, smmap, murmurhash, multimethod, cymem, catalogue, wasabi, visions, typer, srsly, smart-open, scikit-learn, pydantic, preshed, oauthlib, Mako, imagehash, gitdb, blis, waitress, thinc, sqlparse, spacy-loggers, spacy-legacy, sklearn, querystring-parser, pynndescent, prometheus-flask-exporter, phik, pathy, missingno, langcodes, htmlmin, gitpython, funcy, docker, databricks-cli, colorlover, alembic, yellowbrick, umap-learn, textblob, spacy, scikit-plot, pyod, pyLDAvis, pandas-profiling, mlxtend, mlflow, kmodes, imbalanced-learn, cufflinks, catboost, pycaret
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 302
#     Uninstalling pywin32-302:
#       Successfully uninstalled pywin32-302
#   Rolling back uninstall of pywin32
#   Moving to c:\users\ai\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#    from C:\Users\AI\AppData\Local\Temp\pip-uninstall-jwdvpcrj\pythoncom.cpython-39.pyc
#   Moving to c:\users\ai\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\ai\anaconda3\lib\site-packages\isapi
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\ai\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\AI\AppData\Local\Temp\pip-uninstall-01ejn5yf\pythoncom.py
#   Moving to c:\users\ai\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\ai\anaconda3\lib\site-packages\pywin32-302-py3.9.egg-info
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~ywin32-302-py3.9.egg-info
#   Moving to c:\users\ai\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\AI\Anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\ai\anaconda3\lib\site-packages\win32com
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\ai\anaconda3\lib\site-packages\win32comext
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~in32comext
#       Note: if you need reliable uninstall behavior, then install
#       with pip instead of using `setup.py install`:
#
#         - `pip install .`       (from a git repo or downloaded source
#                                  release)
#         - `pip install numpy`   (last NumPy release on PyPi)
#
#
#       blas_opt_info:
#       blas_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       blis_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blis not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       customize GnuFCompiler
#       Could not locate executable g77
#       Could not locate executable f77
#       customize IntelVisualFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifl
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       customize CompaqVisualFCompiler
#       Could not locate executable DF
#       customize IntelItaniumVisualFCompiler
#       Could not locate executable efl
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize G95FCompiler
#       Could not locate executable g95
#       customize IntelEM64VisualFCompiler
#       customize IntelEM64TFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize PGroupFlangCompiler
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       accelerate_info:
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#       배치 파일이 아닙니다.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_clapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas,lapack not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       flame_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries flame not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\Users\AI\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\Users\AI\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\AI\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\Users\AI\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       lapack_src_info:
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-q4qrxtkl\numpy_720f599b2b2846f6b396e9eff923bbde\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#         NOT AVAILABLE
#
#       C:\Users\AI\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       C:\Users\AI\Anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'C:\Users\AI\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-q4qrxtkl\\numpy_720f599b2b2846f6b396e9eff923bbde\\setup.py'"'"'; __file__='"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-q4qrxtkl\\numpy_720f599b2b2846f6b396e9eff923bbde\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\AI\AppData\Local\Temp\pip-record-i50v5avp\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\AI\AppData\Local\Temp\pip-build-env-j53d_3x3\overlay' --compile --install-headers 'C:\Users\AI\AppData\Local\Temp\pip-build-env-j53d_3x3\overlay\Include\numpy' Check the logs for full command output.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/f6/75297be19f48b7a8c2577753a3a700f98fc4db49d0e5ed3820dd8dee43d4/scikit-learn-0.23.2.tar.gz#sha256=20766f515e6cd6f954554387dfae705d93c7b544ec0e6c6a5d8e006f6f7ef480 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\AI\Anaconda3\python.exe' 'C:\Users\AI\AppData\Local\Temp\pip-standalone-pip-i7q3wms5\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\AI\AppData\Local\Temp\pip-build-env-j53d_3x3\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\AI\\Anaconda3\\Lib\\site-packages\\pywin32_system32\\pywintypes39.dll'
# Consider using the `--user` option or check the permissions.

# %%
from pycaret.datasets import get_data
data = get_data('train')
data.info()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 from pycaret.datasets import get_data
#       2 data = get_data('train')
#       3 data.info()
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
from pycaret.classification import *
clf = setup(data=train, session_id=999, high_cardinality_features=['native-country'], target='income',
            use_gpu=False, silent=True, fix_imbalance=False, normalize=True, feature_selection=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 from pycaret.classification import *
#       2 clf = setup(data=train, session_id=999, high_cardinality_features=['native-country'], target='income',
#       3             use_gpu=False, silent=True, fix_imbalance=False, normalize=True, feature_selection=False)
#
# ModuleNotFoundError: No module named 'pycaret'

# %%
# !pip install bottleneck
# !pip install p5py
# !pip install pep517
# Out:
# Requirement already satisfied: bottleneck in c:\users\ai\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy in c:\users\ai\anaconda3\lib\site-packages (from bottleneck) (1.21.5)
# Collecting p5py
#   Downloading p5py-1.0.0.tar.gz (2.9 kB)
# Building wheels for collected packages: p5py
#   Building wheel for p5py (setup.py): started
#   Building wheel for p5py (setup.py): finished with status 'done'
#   Created wheel for p5py: filename=p5py-1.0.0-py2.py3-none-any.whl size=2333 sha256=8f080cde68f9623dc283ac84b53ca12ac34bcac2307585651c2c22b6fd817c3e
#   Stored in directory: c:\users\ai\appdata\local\pip\cache\wheels\72\c3\3e\d2e21f7f687d90134f4774eee0b36f1b3303ef35d4ebf832c7
# Successfully built p5py
# Installing collected packages: p5py
# Successfully installed p5py-1.0.0
# Collecting pep517
#   Downloading pep517-0.12.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\ai\anaconda3\lib\site-packages (from pep517) (1.2.2)
# Installing collected packages: pep517
# Successfully installed pep517-0.12.0

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ai\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\ai\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pillow in c:\users\ai\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\ai\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
# !pip install pycaret[full]
# Out:
# Collecting pycaret[full]
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# Requirement already satisfied: IPython in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (8.2.0)
# Collecting numba<0.55
#   Using cached numba-0.54.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting umap-learn
#   Using cached umap_learn-0.5.3-py3-none-any.whl
# Requirement already satisfied: ipywidgets in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (7.6.5)
# Collecting scikit-plot
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Requirement already satisfied: pandas in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (1.4.2)
# Requirement already satisfied: nltk in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (3.7)
# Collecting scikit-learn==0.23.2
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Collecting pycaret[full]
#   Using cached pycaret-2.3.9-py3-none-any.whl (319 kB)
#   Using cached pycaret-2.3.8-py3-none-any.whl (318 kB)
#   Using cached pycaret-2.3.7-py3-none-any.whl (318 kB)
#   Using cached pycaret-2.3.6-py3-none-any.whl (301 kB)
#   Using cached pycaret-2.3.5-py3-none-any.whl (288 kB)
# Collecting numpy==1.19.5
#   Using cached numpy-1.19.5-cp39-cp39-win_amd64.whl (13.3 MB)
# Collecting pycaret[full]
#   Using cached pycaret-2.3.4-py3-none-any.whl (266 kB)
# Collecting numba<0.54
#   Using cached numba-0.53.1-cp39-cp39-win_amd64.whl (2.3 MB)
# Collecting pycaret[full]
#   Using cached pycaret-2.3.3-py3-none-any.whl (264 kB)
#   Using cached pycaret-2.3.2-py3-none-any.whl (263 kB)
#   Using cached pycaret-2.3.1-py3-none-any.whl (261 kB)
#   Using cached pycaret-2.3.0-py3-none-any.whl (261 kB)
# Collecting mlxtend
#   Using cached mlxtend-0.20.0-py2.py3-none-any.whl (1.3 MB)
# Collecting pycaret[full]
#   Using cached pycaret-2.2.3-py3-none-any.whl (249 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (1.21.5)
#   Using cached pycaret-2.2.2-py3-none-any.whl (249 kB)
# Collecting pandas-profiling>=2.8.0
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Requirement already satisfied: seaborn in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (0.11.2)
# Requirement already satisfied: gensim in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (4.1.2)
# Requirement already satisfied: joblib in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (1.1.0)
# Collecting imbalanced-learn>=0.7.0
#   Using cached imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
# Collecting textblob
#   Using cached textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Collecting pyod
#   Using cached pyod-1.0.3-py3-none-any.whl
# Requirement already satisfied: lightgbm>=2.3.1 in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (3.3.2)
# Collecting cufflinks>=0.17.0
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# Collecting catboost>=0.23.2
#   Using cached catboost-1.0.6-cp39-none-win_amd64.whl (73.9 MB)
# Requirement already satisfied: wordcloud in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (1.8.2.2)
# Requirement already satisfied: plotly>=4.4.1 in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (5.6.0)
# Requirement already satisfied: scikit-learn>=0.23.2 in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (1.0.2)
# Requirement already satisfied: matplotlib in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (3.5.1)
# Collecting spacy
#   Using cached spacy-3.4.0-cp39-cp39-win_amd64.whl (11.8 MB)
# Collecting yellowbrick>=1.0.1
#   Using cached yellowbrick-1.4-py3-none-any.whl (274 kB)
# Collecting kmodes>=0.10.1
#   Using cached kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.3.1-py2.py3-none-any.whl
# Collecting mlflow
#   Using cached mlflow-1.27.0-py3-none-any.whl (17.9 MB)
# Requirement already satisfied: xgboost>=1.1.0 in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (1.6.1)
# Requirement already satisfied: psutil in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (5.8.0)
# Collecting shap
#   Downloading shap-0.41.0-cp39-cp39-win_amd64.whl (435 kB)
# Collecting scikit-optimize>=0.8.1
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.13.0-py3-none-any.whl (377 kB)
# Collecting optuna
#   Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
# Collecting ray[tune]>=1.0.0
#   Downloading ray-1.13.0-cp39-cp39-win_amd64.whl (20.3 MB)
# Requirement already satisfied: google-cloud-storage in c:\users\ai\anaconda3\lib\site-packages (from pycaret[full]) (1.31.0)
# Collecting tune-sklearn>=0.1.0
#   Downloading tune_sklearn-0.4.3-py3-none-any.whl (40 kB)
# Collecting awscli
#   Downloading awscli-1.25.35-py3-none-any.whl (3.9 MB)
# Requirement already satisfied: six in c:\users\ai\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret[full]) (1.16.0)
# Requirement already satisfied: scipy in c:\users\ai\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret[full]) (1.7.3)
# Requirement already satisfied: graphviz in c:\users\ai\anaconda3\lib\site-packages (from catboost>=0.23.2->pycaret[full]) (0.20)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\ai\anaconda3\lib\site-packages (from cufflinks>=0.17.0->pycaret[full]) (61.2.0)
# Collecting colorlover>=0.2.1
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Collecting scikit-learn>=0.23.2
#   Using cached scikit_learn-1.1.1-cp39-cp39-win_amd64.whl (7.4 MB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ai\anaconda3\lib\site-packages (from imbalanced-learn>=0.7.0->pycaret[full]) (2.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (0.1.2)
# Requirement already satisfied: backcall in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (0.18.1)
# Requirement already satisfied: decorator in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (2.11.2)
# Requirement already satisfied: traitlets>=5 in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (5.1.1)
# Requirement already satisfied: colorama in c:\users\ai\anaconda3\lib\site-packages (from IPython->pycaret[full]) (0.4.4)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret[full]) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret[full]) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret[full]) (6.9.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret[full]) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ai\anaconda3\lib\site-packages (from ipywidgets->pycaret[full]) (3.5.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\ai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (6.1)
# Requirement already satisfied: nest-asyncio in c:\users\ai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (1.5.5)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ai\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets->pycaret[full]) (6.1.12)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ai\anaconda3\lib\site-packages (from jedi>=0.16->IPython->pycaret[full]) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\ai\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret[full]) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ai\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret[full]) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ai\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret[full]) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ai\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets->pycaret[full]) (302)
# Requirement already satisfied: wheel in c:\users\ai\anaconda3\lib\site-packages (from lightgbm>=2.3.1->pycaret[full]) (0.37.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ai\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret[full]) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\ai\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->pycaret[full]) (2.15.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ai\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret[full]) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ai\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->pycaret[full]) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ai\anaconda3\lib\site-packages (from pandas->pycaret[full]) (2021.3)
# Collecting markupsafe~=2.1.1
#   Using cached MarkupSafe-2.1.1-cp39-cp39-win_amd64.whl (17 kB)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\ai\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (6.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\ai\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (4.64.0)
# Collecting phik>=0.11.1
#   Using cached phik-0.12.2-cp39-cp39-win_amd64.whl (685 kB)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12-py3-none-any.whl
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\ai\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (2.11.3)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Collecting pydantic>=1.8.1
#   Using cached pydantic-1.9.1-cp39-cp39-win_amd64.whl (2.0 MB)
# Collecting tangled-up-in-unicode==0.2.0
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\ai\anaconda3\lib\site-packages (from pandas-profiling>=2.8.0->pycaret[full]) (2.27.1)
# Collecting multimethod>=1.4
#   Using cached multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: networkx>=2.4 in c:\users\ai\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret[full]) (2.7.1)
# Requirement already satisfied: Pillow in c:\users\ai\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret[full]) (9.0.1)
# Collecting imagehash
#   Using cached ImageHash-4.2.1-py2.py3-none-any.whl
# Requirement already satisfied: packaging>=20.0 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret[full]) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret[full]) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret[full]) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret[full]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ai\anaconda3\lib\site-packages (from matplotlib->pycaret[full]) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ai\anaconda3\lib\site-packages (from plotly>=4.4.1->pycaret[full]) (8.0.1)
# Requirement already satisfied: wcwidth in c:\users\ai\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->pycaret[full]) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ai\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling>=2.8.0->pycaret[full]) (4.1.1)
# Requirement already satisfied: frozenlist in c:\users\ai\anaconda3\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.2.0)
# Requirement already satisfied: click<=8.0.4,>=7.0 in c:\users\ai\anaconda3\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (8.0.4)
# Requirement already satisfied: filelock in c:\users\ai\anaconda3\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (3.6.0)
# Requirement already satisfied: aiosignal in c:\users\ai\anaconda3\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.2.0)
# Collecting virtualenv
#   Downloading virtualenv-20.15.1-py2.py3-none-any.whl (10.1 MB)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\ai\anaconda3\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.0.2)
# Requirement already satisfied: protobuf<4.0.0,>=3.15.3 in c:\users\ai\anaconda3\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (3.19.1)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in c:\users\ai\anaconda3\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (1.42.0)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: tabulate in c:\users\ai\anaconda3\lib\site-packages (from ray[tune]>=1.0.0->pycaret[full]) (0.8.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret[full]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret[full]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret[full]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ai\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling>=2.8.0->pycaret[full]) (1.26.9)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ai\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (6.4.8)
# Requirement already satisfied: prometheus-client in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (6.4.4)
# Requirement already satisfied: argon2-cffi in c:\users\ai\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ai\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ai\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ai\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ai\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (2.21)
# Collecting PyYAML>=5.0.0
#   Using cached PyYAML-5.4.1-cp39-cp39-win_amd64.whl (213 kB)
# Collecting docutils<0.17,>=0.10
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in c:\users\ai\anaconda3\lib\site-packages (from awscli->pycaret[full]) (4.7.2)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
# Collecting botocore==1.27.35
#   Downloading botocore-1.27.35-py3-none-any.whl (9.0 MB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\ai\anaconda3\lib\site-packages (from botocore==1.27.35->awscli->pycaret[full]) (0.10.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ai\anaconda3\lib\site-packages (from rsa<4.8,>=3.1.2->awscli->pycaret[full]) (0.4.8)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\ai\anaconda3\lib\site-packages (from azure-storage-blob->pycaret[full]) (3.4.8)
# Collecting msrest>=0.6.21
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
# Collecting azure-core<2.0.0,>=1.23.1
#   Downloading azure_core-1.24.2-py3-none-any.whl (178 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\ai\anaconda3\lib\site-packages (from gensim->pycaret[full]) (5.1.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in c:\users\ai\anaconda3\lib\site-packages (from google-cloud-storage->pycaret[full]) (1.7.1)
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in c:\users\ai\anaconda3\lib\site-packages (from google-cloud-storage->pycaret[full]) (1.33.0)
# Requirement already satisfied: google-resumable-media<2.0dev,>=1.0.0 in c:\users\ai\anaconda3\lib\site-packages (from google-cloud-storage->pycaret[full]) (1.3.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\ai\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->pycaret[full]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ai\anaconda3\lib\site-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage->pycaret[full]) (0.2.8)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.21.0 in c:\users\ai\anaconda3\lib\site-packages (from google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage->pycaret[full]) (1.25.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\ai\anaconda3\lib\site-packages (from google-api-core<2.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage->pycaret[full]) (1.53.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\ai\anaconda3\lib\site-packages (from google-resumable-media<2.0dev,>=1.0.0->google-cloud-storage->pycaret[full]) (1.1.2)
# Requirement already satisfied: cloudpickle in c:\users\ai\anaconda3\lib\site-packages (from hyperopt->pycaret[full]) (2.0.0)
# Requirement already satisfied: future in c:\users\ai\anaconda3\lib\site-packages (from hyperopt->pycaret[full]) (0.18.2)
# Collecting py4j
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
# Requirement already satisfied: PyWavelets in c:\users\ai\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling>=2.8.0->pycaret[full]) (1.3.0)
# Requirement already satisfied: sqlalchemy>=1.4.0 in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret[full]) (1.4.32)
# Collecting gitpython>=2.1.0
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Collecting docker>=4.0.0
#   Using cached docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting databricks-cli>=0.8.7
#   Using cached databricks_cli-0.17.0-py3-none-any.whl
# Collecting querystring-parser
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting waitress
#   Using cached waitress-2.1.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret[full]) (4.11.3)
# Collecting sqlparse>=0.3.1
#   Using cached sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Requirement already satisfied: entrypoints in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret[full]) (0.4)
# Requirement already satisfied: Flask in c:\users\ai\anaconda3\lib\site-packages (from mlflow->pycaret[full]) (1.1.2)
# Collecting prometheus-flask-exporter
#   Using cached prometheus_flask_exporter-0.20.2-py3-none-any.whl (18 kB)
# Collecting alembic
#   Using cached alembic-1.8.1-py3-none-any.whl (209 kB)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\ai\anaconda3\lib\site-packages (from databricks-cli>=0.8.7->mlflow->pycaret[full]) (2.1.0)
# Collecting pywin32>=1.0
#   Using cached pywin32-227-cp39-cp39-win_amd64.whl (9.1 MB)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\ai\anaconda3\lib\site-packages (from docker>=4.0.0->mlflow->pycaret[full]) (0.58.0)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in c:\users\ai\anaconda3\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->pycaret[full]) (3.7.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ai\anaconda3\lib\site-packages (from sqlalchemy>=1.4.0->mlflow->pycaret[full]) (1.1.1)
# Collecting Mako
#   Using cached Mako-1.2.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\ai\anaconda3\lib\site-packages (from Flask->mlflow->pycaret[full]) (2.0.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\ai\anaconda3\lib\site-packages (from Flask->mlflow->pycaret[full]) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (0.1.2)
# Requirement already satisfied: testpath in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (4.11.1)
# Requirement already satisfied: bleach in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ai\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (1.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ai\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\ai\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->pycaret[full]) (0.5.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ai\anaconda3\lib\site-packages (from nltk->pycaret[full]) (2022.3.15)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-4.0.0-py3-none-any.whl (49 kB)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.2-py3-none-any.whl (147 kB)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting PrettyTable>=0.7.2
#   Downloading prettytable-3.3.0-py3-none-any.whl (26 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Collecting funcy
#   Using cached funcy-1.17-py2.py3-none-any.whl (33 kB)
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Requirement already satisfied: numexpr in c:\users\ai\anaconda3\lib\site-packages (from pyLDAvis->pycaret[full]) (2.8.1)
# Requirement already satisfied: statsmodels in c:\users\ai\anaconda3\lib\site-packages (from pyod->pycaret[full]) (0.13.2)
# Requirement already satisfied: numba>=0.51 in c:\users\ai\anaconda3\lib\site-packages (from pyod->pycaret[full]) (0.55.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\ai\anaconda3\lib\site-packages (from numba>=0.51->pyod->pycaret[full]) (0.38.0)
# Collecting slicer==0.0.7
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp39-cp39-win_amd64.whl (36 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.3-py3-none-any.whl (9.3 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Using cached spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.6-cp39-cp39-win_amd64.whl (112 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.4-cp39-cp39-win_amd64.whl (450 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Using cached typer-0.4.2-py3-none-any.whl (27 kB)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.2-py3-none-any.whl (42 kB)
# Collecting wasabi<1.1.0,>=0.9.1
#   Using cached wasabi-0.9.1-py3-none-any.whl (26 kB)
# Collecting thinc<8.2.0,>=8.1.0
#   Using cached thinc-8.1.0-cp39-cp39-win_amd64.whl (1.3 MB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.7-cp39-cp39-win_amd64.whl (18 kB)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.8-cp39-cp39-win_amd64.whl (6.6 MB)
# Requirement already satisfied: pure-eval in c:\users\ai\anaconda3\lib\site-packages (from stack-data->IPython->pycaret[full]) (0.2.2)
# Requirement already satisfied: executing in c:\users\ai\anaconda3\lib\site-packages (from stack-data->IPython->pycaret[full]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ai\anaconda3\lib\site-packages (from stack-data->IPython->pycaret[full]) (2.0.5)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\ai\anaconda3\lib\site-packages (from statsmodels->pyod->pycaret[full]) (0.5.2)
# Collecting pynndescent>=0.5
#   Using cached pynndescent-0.5.7-py3-none-any.whl
# Collecting distlib<1,>=0.3.1
#   Downloading distlib-0.3.5-py2.py3-none-any.whl (466 kB)
# Collecting platformdirs<3,>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=60267a5509c79f2de85bf30e173ef9f12132a49b5452428a98a448ed743499ad
#   Stored in directory: c:\users\ai\appdata\local\pip\cache\wheels\0c\09\9e\49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
# Successfully built pyperclip
# Installing collected packages: pywin32, markupsafe, tangled-up-in-unicode, smmap, platformdirs, murmurhash, multimethod, distlib, cymem, catalogue, wasabi, visions, virtualenv, typer, srsly, smart-open, scikit-learn, PyYAML, pyreadline3, pyperclip, pydantic, preshed, pbr, oauthlib, Mako, imagehash, gitdb, blis, waitress, thinc, tensorboardX, stevedore, sqlparse, spacy-loggers, spacy-legacy, sklearn, requests-oauthlib, ray, querystring-parser, pynndescent, prometheus-flask-exporter, PrettyTable, phik, pathy, missingno, langcodes, isodate, htmlmin, gitpython, funcy, docker, databricks-cli, colorlover, cmd2, botocore, azure-core, autopage, alembic, yellowbrick, umap-learn, textblob, spacy, slicer, scikit-plot, s3transfer, pyod, pyLDAvis, pyaml, py4j, pandas-profiling, msrest, mlxtend, mlflow, kmodes, imbalanced-learn, docutils, cufflinks, colorlog, cmaes, cliff, catboost, tune-sklearn, shap, scikit-optimize, pycaret, optuna, hyperopt, azure-storage-blob, awscli
#   Attempting uninstall: pywin32
#     Found existing installation: pywin32 302
#     Uninstalling pywin32-302:
#       Successfully uninstalled pywin32-302
#   Rolling back uninstall of pywin32
#   Moving to c:\users\ai\anaconda3\lib\site-packages\__pycache__\pythoncom.cpython-39.pyc
#    from C:\Users\AI\AppData\Local\Temp\pip-uninstall-4xd5kz_w\pythoncom.cpython-39.pyc
#   Moving to c:\users\ai\anaconda3\lib\site-packages\adodbapi
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~dodbapi
#   Moving to c:\users\ai\anaconda3\lib\site-packages\isapi
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~sapi
#   Moving to c:\users\ai\anaconda3\lib\site-packages\pythoncom.py
#    from C:\Users\AI\AppData\Local\Temp\pip-uninstall-qvept2gp\pythoncom.py
#   Moving to c:\users\ai\anaconda3\lib\site-packages\pythonwin
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~ythonwin
#   Moving to c:\users\ai\anaconda3\lib\site-packages\pywin32-302-py3.9.egg-info
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~ywin32-302-py3.9.egg-info
#   Moving to c:\users\ai\anaconda3\lib\site-packages\win32\lib\
#    from C:\Users\AI\Anaconda3\Lib\site-packages\win32\~ib
#   Moving to c:\users\ai\anaconda3\lib\site-packages\win32com
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~in32com
#   Moving to c:\users\ai\anaconda3\lib\site-packages\win32comext
#    from C:\Users\AI\Anaconda3\Lib\site-packages\~in32comext
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\AI\Anaconda3\python.exe' 'C:\Users\AI\AppData\Local\Temp\pip-standalone-pip-3smsona6\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\AI\AppData\Local\Temp\pip-build-env-g2bv9fwu\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1'
#        cwd: None
#   Complete output (595 lines):
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation != "CPython"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system != "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.6" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version == "3.7" and platform_system == "AIX"' don't match your environment
#   Ignoring numpy: markers 'python_version >= "3.8" and platform_system == "AIX"' don't match your environment
#   Collecting setuptools
#     Using cached setuptools-63.2.0-py3-none-any.whl (1.2 MB)
#   Collecting wheel
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
#   Collecting Cython>=0.28.5
#     Using cached Cython-0.29.30-py2.py3-none-any.whl (985 kB)
#   Collecting numpy==1.17.3
#     Using cached numpy-1.17.3.zip (6.4 MB)
#   Collecting scipy>=0.19.1
#     Using cached scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
#   Building wheels for collected packages: numpy
#     Building wheel for numpy (setup.py): started
#     Building wheel for numpy (setup.py): finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\AI\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-c3v5kf3k\\numpy_42f6888ac2594384b1ab5af479d6c658\\setup.py'"'"'; __file__='"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-c3v5kf3k\\numpy_42f6888ac2594384b1ab5af479d6c658\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\AI\AppData\Local\Temp\pip-wheel-ci1l5m4g'
#          cwd: C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\
#     Complete output (268 lines):
#     Running from numpy source directory.
#     blas_opt_info:
#     blas_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     blis_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blis not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#     get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#     customize GnuFCompiler
#     Could not locate executable g77
#     Could not locate executable f77
#     customize IntelVisualFCompiler
#     Could not locate executable ifort
#     Could not locate executable ifl
#     customize AbsoftFCompiler
#     Could not locate executable f90
#     customize CompaqVisualFCompiler
#     Could not locate executable DF
#     customize IntelItaniumVisualFCompiler
#     Could not locate executable efl
#     customize Gnu95FCompiler
#     Could not locate executable gfortran
#     Could not locate executable f95
#     customize G95FCompiler
#     Could not locate executable g95
#     customize IntelEM64VisualFCompiler
#     customize IntelEM64TFCompiler
#     Could not locate executable efort
#     Could not locate executable efc
#     customize PGroupFlangCompiler
#     Could not locate executable flang
#     don't know how to compile Fortran code on platform 'nt'
#       NOT AVAILABLE
#
#     atlas_3_10_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     accelerate_info:
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:690: UserWarning:
#         Optimized (vendor) Blas libraries are not found.
#         Falls back to netlib Blas library which has worse performance.
#         A better performance should be easily gained by switching
#         Blas library.
#       self.calc_info()
#     blas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries blas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [blas]) or by setting
#         the BLAS environment variable.
#       self.calc_info()
#     blas_src_info:
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:690: UserWarning:
#         Blas (http://www.netlib.org/blas/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [blas_src]) or by setting
#         the BLAS_SRC environment variable.
#       self.calc_info()
#       NOT AVAILABLE
#
#     'svnversion'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#     배치 파일이 아닙니다.
#     non-existing path in 'numpy\\distutils': 'site.cfg'
#     lapack_opt_info:
#     lapack_mkl_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries mkl_rt not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     openblas_clapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries openblas,lapack not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     flame_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries flame not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     atlas_3_10_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries tatlas,tatlas not found in C:\Users\AI\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#       NOT AVAILABLE
#
#     atlas_3_10_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries satlas,satlas not found in C:\Users\AI\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_3_10_info'>
#       NOT AVAILABLE
#
#     atlas_threads_info:
#     Setting PTATLAS=ATLAS
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries ptf77blas,ptcblas,atlas not found in C:\Users\AI\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_threads_info'>
#       NOT AVAILABLE
#
#     atlas_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\AI\Anaconda3\lib
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries f77blas,cblas,atlas not found in C:\Users\AI\Anaconda3\libs
#     <class 'numpy.distutils.system_info.atlas_info'>
#       NOT AVAILABLE
#
#     lapack_info:
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     customize MSVCCompiler
#       libraries lapack not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) libraries not found.
#         Directories to search for the libraries can be specified in the
#         numpy/distutils/site.cfg file (section [lapack]) or by setting
#         the LAPACK environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#     lapack_src_info:
#       NOT AVAILABLE
#
#     C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:1712: UserWarning:
#         Lapack (http://www.netlib.org/lapack/) sources not found.
#         Directories to search for the sources can be specified in the
#         numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#         the LAPACK_SRC environment variable.
#       if getattr(self, '_calc_info_{}'.format(lapack))():
#       NOT AVAILABLE
#
#     C:\Users\AI\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#       warnings.warn(msg)
#     running bdist_wheel
#     running build
#     running config_cc
#     unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#     running config_fc
#     unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#     running build_src
#     build_src
#     building py_modules sources
#     creating build
#     creating build\src.win-amd64-3.9
#     creating build\src.win-amd64-3.9\numpy
#     creating build\src.win-amd64-3.9\numpy\distutils
#     building library "npymath" sources
#     No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
#     ERROR: Failed building wheel for numpy
#     Running setup.py clean for numpy
# ...
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#       get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#       customize GnuFCompiler
#       Could not locate executable g77
#       Could not locate executable f77
#       customize IntelVisualFCompiler
#       Could not locate executable ifort
#       Could not locate executable ifl
#       customize AbsoftFCompiler
#       Could not locate executable f90
#       customize CompaqVisualFCompiler
#       Could not locate executable DF
#       customize IntelItaniumVisualFCompiler
#       Could not locate executable efl
#       customize Gnu95FCompiler
#       Could not locate executable gfortran
#       Could not locate executable f95
#       customize G95FCompiler
#       Could not locate executable g95
#       customize IntelEM64VisualFCompiler
#       customize IntelEM64TFCompiler
#       Could not locate executable efort
#       Could not locate executable efc
#       customize PGroupFlangCompiler
#       Could not locate executable flang
#       don't know how to compile Fortran code on platform 'nt'
#         NOT AVAILABLE
#
#       atlas_3_10_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       accelerate_info:
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:690: UserWarning:
#           Optimized (vendor) Blas libraries are not found.
#           Falls back to netlib Blas library which has worse performance.
#           A better performance should be easily gained by switching
#           Blas library.
#         self.calc_info()
#       blas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries blas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [blas]) or by setting
#           the BLAS environment variable.
#         self.calc_info()
#       blas_src_info:
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:690: UserWarning:
#           Blas (http://www.netlib.org/blas/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [blas_src]) or by setting
#           the BLAS_SRC environment variable.
#         self.calc_info()
#         NOT AVAILABLE
#
#       'svnversion'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
#       배치 파일이 아닙니다.
#       non-existing path in 'numpy\\distutils': 'site.cfg'
#       lapack_opt_info:
#       lapack_mkl_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries mkl_rt not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       openblas_clapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries openblas,lapack not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       flame_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries flame not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       atlas_3_10_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries tatlas,tatlas not found in C:\Users\AI\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_threads_info'>
#         NOT AVAILABLE
#
#       atlas_3_10_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries satlas,satlas not found in C:\Users\AI\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_3_10_info'>
#         NOT AVAILABLE
#
#       atlas_threads_info:
#       Setting PTATLAS=ATLAS
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries ptf77blas,ptcblas,atlas not found in C:\Users\AI\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_threads_info'>
#         NOT AVAILABLE
#
#       atlas_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\Users\AI\Anaconda3\lib
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack_atlas not found in C:\Users\AI\Anaconda3\libs
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries f77blas,cblas,atlas not found in C:\Users\AI\Anaconda3\libs
#       <class 'numpy.distutils.system_info.atlas_info'>
#         NOT AVAILABLE
#
#       lapack_info:
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       customize MSVCCompiler
#         libraries lapack not found in ['C:\\Users\\AI\\Anaconda3\\lib', 'C:\\', 'C:\\Users\\AI\\Anaconda3\\libs']
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) libraries not found.
#           Directories to search for the libraries can be specified in the
#           numpy/distutils/site.cfg file (section [lapack]) or by setting
#           the LAPACK environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#       lapack_src_info:
#         NOT AVAILABLE
#
#       C:\Users\AI\AppData\Local\Temp\pip-install-c3v5kf3k\numpy_42f6888ac2594384b1ab5af479d6c658\numpy\distutils\system_info.py:1712: UserWarning:
#           Lapack (http://www.netlib.org/lapack/) sources not found.
#           Directories to search for the sources can be specified in the
#           numpy/distutils/site.cfg file (section [lapack_src]) or by setting
#           the LAPACK_SRC environment variable.
#         if getattr(self, '_calc_info_{}'.format(lapack))():
#         NOT AVAILABLE
#
#       C:\Users\AI\Anaconda3\lib\site-packages\setuptools\_distutils\dist.py:275: UserWarning: Unknown distribution option: 'define_macros'
#         warnings.warn(msg)
#       running install
#       C:\Users\AI\Anaconda3\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running config_cc
#       unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#       running config_fc
#       unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#       running build_src
#       build_src
#       building py_modules sources
#       building library "npymath" sources
#       No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       ----------------------------------------
#   ERROR: Command errored out with exit status 1: 'C:\Users\AI\Anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-c3v5kf3k\\numpy_42f6888ac2594384b1ab5af479d6c658\\setup.py'"'"'; __file__='"'"'C:\\Users\\AI\\AppData\\Local\\Temp\\pip-install-c3v5kf3k\\numpy_42f6888ac2594384b1ab5af479d6c658\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\AI\AppData\Local\Temp\pip-record-o00g6c9_\install-record.txt' --single-version-externally-managed --prefix 'C:\Users\AI\AppData\Local\Temp\pip-build-env-g2bv9fwu\overlay' --compile --install-headers 'C:\Users\AI\AppData\Local\Temp\pip-build-env-g2bv9fwu\overlay\Include\numpy' Check the logs for full command output.
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/aa/f6/75297be19f48b7a8c2577753a3a700f98fc4db49d0e5ed3820dd8dee43d4/scikit-learn-0.23.2.tar.gz#sha256=20766f515e6cd6f954554387dfae705d93c7b544ec0e6c6a5d8e006f6f7ef480 (from https://pypi.org/simple/scikit-learn/) (requires-python:>=3.6). Command errored out with exit status 1: 'C:\Users\AI\Anaconda3\python.exe' 'C:\Users\AI\AppData\Local\Temp\pip-standalone-pip-3smsona6\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\AI\AppData\Local\Temp\pip-build-env-g2bv9fwu\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools wheel 'Cython>=0.28.5' 'numpy==1.13.3; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation == '"'"'CPython'"'"'' 'numpy==1.14.0; python_version=='"'"'3.6'"'"' and platform_system!='"'"'AIX'"'"' and platform_python_implementation != '"'"'CPython'"'"'' 'numpy==1.14.5; python_version=='"'"'3.7'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system!='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.6'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.16.0; python_version=='"'"'3.7'"'"' and platform_system=='"'"'AIX'"'"'' 'numpy==1.17.3; python_version>='"'"'3.8'"'"' and platform_system=='"'"'AIX'"'"'' 'scipy>=0.19.1' Check the logs for full command output.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\AI\\Anaconda3\\Lib\\site-packages\\pywin32_system32\\pywintypes39.dll'
# Consider using the `--user` option or check the permissions.

# %%
conda create --name yourenvname python=3.8

# %%
from pycaret.classification import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from pycaret.classification import *
#
# ModuleNotFoundError: No module named 'pycaret'
