# %% [markdown]
# # 데이터 수집

# %%
import pandas as pd

train = pd.read_csv("./train.csv")
test = pd.read_csv("./test.csv")

# %%
print(train.shape)
print(test.shape)
# Out:
# (29305, 16)
# (19537, 15)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29305 entries, 0 to 29304
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   no              29305 non-null  int64
#  1   age             29305 non-null  int64
#  2   workclass       29305 non-null  object
#  3   fnlwgt          29305 non-null  int64
#  4   education       29305 non-null  object
#  5   education-num   29305 non-null  int64
#  6   marital-status  29305 non-null  object
#  7   occupation      29305 non-null  object
#  8   relationship    29305 non-null  object
#  9   race            29305 non-null  object
#  10  sex             29305 non-null  object
#  11  capital-gain    29305 non-null  int64
#  12  capital-loss    29305 non-null  int64
#  13  hours-per-week  29305 non-null  int64
#  14  native-country  29305 non-null  object
#  15  income          29305 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 3.6+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19537 entries, 0 to 19536
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   no              19537 non-null  int64
#  1   age             19537 non-null  int64
#  2   workclass       19537 non-null  object
#  3   fnlwgt          19537 non-null  int64
#  4   education       19537 non-null  object
#  5   education-num   19537 non-null  int64
#  6   marital-status  19537 non-null  object
#  7   occupation      19537 non-null  object
#  8   relationship    19537 non-null  object
#  9   race            19537 non-null  object
#  10  sex             19537 non-null  object
#  11  capital-gain    19537 non-null  int64
#  12  capital-loss    19537 non-null  int64
#  13  hours-per-week  19537 non-null  int64
#  14  native-country  19537 non-null  object
# dtypes: int64(7), object(8)
# memory usage: 2.2+ MB

# %%
train.isnull().sum()
# Out:
# no                0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# no                0
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# dtype: int64

# %%
test.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19537 entries, 0 to 19536
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   no              19537 non-null  bool
#  1   age             19537 non-null  bool
#  2   workclass       19537 non-null  bool
#  3   fnlwgt          19537 non-null  bool
#  4   education       19537 non-null  bool
#  5   education-num   19537 non-null  bool
#  6   marital-status  19537 non-null  bool
#  7   occupation      19537 non-null  bool
#  8   relationship    19537 non-null  bool
#  9   race            19537 non-null  bool
#  10  sex             19537 non-null  bool
#  11  capital-gain    19537 non-null  bool
#  12  capital-loss    19537 non-null  bool
#  13  hours-per-week  19537 non-null  bool
#  14  native-country  19537 non-null  bool
# dtypes: bool(15)
# memory usage: 286.3 KB

# %%
train.describe()
# Out:
#                  no           age        fnlwgt  education-num  capital-gain  \
# count  29305.000000  29305.000000  2.930500e+04   29305.000000  29305.000000
# mean   14653.000000     38.659171  1.897357e+05      10.083057   1084.531786
# std     8459.769156     13.743827  1.056348e+05       2.570371   7495.715677
# min        1.000000     17.000000  1.376900e+04       1.000000      0.000000
# 25%     7327.000000     28.000000  1.176060e+05       9.000000      0.000000
# 50%    14653.000000     37.000000  1.779550e+05      10.000000      0.000000
# 75%    21979.000000     48.000000  2.377130e+05      12.000000      0.000000
# max    29305.000000     90.000000  1.490400e+06      16.000000  99999.000000
#
#        capital-loss  hours-per-week        income
# count  29305.000000    29305.000000  29305.000000
# mean      87.073571       40.440096      0.240403
# std      401.225580       12.332840      0.427335
# min        0.000000        1.000000      0.000000
# ...

# %%
test.describe()
# Out:
#                 no           age        fnlwgt  education-num  capital-gain  \
# count  19537.00000  19537.000000  1.953700e+04   19537.000000  19537.000000
# mean   39074.00000     38.620208  1.895568e+05      10.070635   1070.871526
# std     5639.99044     13.660701  1.055605e+05       2.571923   7386.174276
# min    29306.00000     17.000000  1.228500e+04       1.000000      0.000000
# 25%    34190.00000     28.000000  1.174770e+05       9.000000      0.000000
# 50%    39074.00000     37.000000  1.783190e+05      10.000000      0.000000
# 75%    43958.00000     48.000000  2.375460e+05      12.000000      0.000000
# max    48842.00000     90.000000  1.484705e+06      16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  19537.000000    19537.000000
# mean      88.145416       40.395813
# std      405.667779       12.479102
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# ...

# %%
train
# Out:
#           no  age          workclass  fnlwgt      education  education-num  \
# 0          1   25            Private  219199           11th              7
# 1          2   39            Private   52978   Some-college             10
# 2          3   35            Private  196899      Bachelors             13
# 3          4   64            Private  135527      Assoc-voc             11
# 4          5   24            Private   60783   Some-college             10
# ...      ...  ...                ...     ...            ...            ...
# 29300  29301   20            Private  100605        HS-grad              9
# 29301  29302   21            Private  372636        HS-grad              9
# 29302  29303   18   Self-emp-not-inc  258474           10th              6
# 29303  29304   33            Private  157446           11th              7
# 29304  29305   65                  ?   94809        HS-grad              9
#
#             marital-status          occupation    relationship  \
# ...

# %%
train.columns
# Out:
# Index(['no', 'age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %% [markdown]
# # 결측치 확인

# %%
train['workclass'].unique()
# Out:
# array([' Private', ' Self-emp-not-inc', ' Local-gov', ' ?', ' State-gov',
#        ' Self-emp-inc', ' Federal-gov', ' Without-pay', ' Never-worked'],
#       dtype=object)

# %%
train['occupation'].unique()
# Out:
# array([' Machine-op-inspct', ' Other-service', ' Handlers-cleaners',
#        ' Tech-support', ' Transport-moving', ' Farming-fishing',
#        ' Prof-specialty', ' Priv-house-serv', ' Adm-clerical',
#        ' Protective-serv', ' Exec-managerial', ' ?', ' Craft-repair',
#        ' Sales', ' Armed-Forces'], dtype=object)

# %%
train['native-country'].unique()
# Out:
# array([' United-States', ' Haiti', ' Mexico', ' Puerto-Rico',
#        ' Philippines', ' ?', ' Germany', ' Peru', ' Ecuador', ' Iran',
#        ' Thailand', ' Dominican-Republic', ' Poland', ' Scotland',
#        ' Italy', ' Jamaica', ' China', ' Portugal', ' Columbia',
#        ' Hungary', ' Vietnam', ' Taiwan', ' Canada', ' Hong',
#        ' Guatemala', ' El-Salvador', ' England',
#        ' Outlying-US(Guam-USVI-etc)', ' India', ' France', ' Cuba',
#        ' Greece', ' Trinadad&Tobago', ' South', ' Japan', ' Yugoslavia',
#        ' Nicaragua', ' Ireland', ' Cambodia', ' Laos', ' Honduras',
#        ' Holand-Netherlands'], dtype=object)

# %%
train["capital-gain"].value_counts()
# Out:
# 0        26883
# 15024      300
# 7688       240
# 7298       204
# 99999      148
#          ...
# 7978         1
# 1264         1
# 6097         1
# 6612         1
# 18481        1
# Name: capital-gain, Length: 117, dtype: int64

# %%
train["workclass"].value_counts()
# Out:
#  Private             20410
#  Self-emp-not-inc     2305
#  Local-gov            1868
#  ?                    1663
#  State-gov            1201
#  Self-emp-inc          987
#  Federal-gov           854
#  Without-pay            12
#  Never-worked            5
# Name: workclass, dtype: int64

# %%
train['occupation'].value_counts()
# Out:
#  Prof-specialty       3724
#  Craft-repair         3632
#  Exec-managerial      3609
#  Adm-clerical         3440
#  Sales                3292
#  Other-service        2975
#  Machine-op-inspct    1811
#  ?                    1668
#  Transport-moving     1393
#  Handlers-cleaners    1249
#  Farming-fishing       888
#  Tech-support          865
#  Protective-serv       603
#  Priv-house-serv       146
#  Armed-Forces           10
# Name: occupation, dtype: int64

# %%
train['native-country'].value_counts()
# Out:
#  United-States                 26301
#  Mexico                          579
#  ?                               495
#  Philippines                     178
#  Germany                         124
#  Puerto-Rico                     117
#  Canada                          111
#  El-Salvador                      96
#  Cuba                             94
#  India                            90
#  England                          75
#  South                            74
#  Jamaica                          68
#  China                            68
#  Dominican-Republic               61
#  Italy                            60
#  Japan                            54
#  Poland                           53
#  Columbia                         53
#  Guatemala                        51
#  Haiti                            51
#  Vietnam                          50
#  Portugal                         43
#  Taiwan                           39
#  Iran                             38
# ...

# %%
train["workclass"] = train["workclass"].replace(" ?", None)
train["occupation"] = train["occupation"].replace(" ?", None)
train["native-country"] = train["native-country"].replace(" ?", None)

# %%
train.isnull().sum()
# Out:
# no                   0
# age                  0
# workclass         1663
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1668
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     495
# income               0
# dtype: int64

# %%
test["workclass"].value_counts()
# Out:
#  Private             13496
#  Self-emp-not-inc     1557
#  Local-gov            1268
#  ?                    1136
#  State-gov             780
#  Self-emp-inc          708
#  Federal-gov           578
#  Without-pay             9
#  Never-worked            5
# Name: workclass, dtype: int64

# %%
test['occupation'].value_counts()
# Out:
#  Craft-repair         2480
#  Exec-managerial      2477
#  Prof-specialty       2448
#  Sales                2212
#  Adm-clerical         2171
#  Other-service        1948
#  Machine-op-inspct    1211
#  ?                    1141
#  Transport-moving      962
#  Handlers-cleaners     823
#  Farming-fishing       602
#  Tech-support          581
#  Protective-serv       380
#  Priv-house-serv        96
#  Armed-Forces            5
# Name: occupation, dtype: int64

# %%
test['native-country'].value_counts()
# Out:
#  United-States                 17531
#  Mexico                          372
#  ?                               362
#  Philippines                     117
#  Germany                          82
#  Canada                           71
#  Puerto-Rico                      67
#  India                            61
#  El-Salvador                      59
#  China                            54
#  England                          52
#  Italy                            45
#  Cuba                             44
#  Dominican-Republic               42
#  South                            41
#  Jamaica                          38
#  Japan                            38
#  Guatemala                        37
#  Vietnam                          36
#  Poland                           34
#  Columbia                         32
#  Taiwan                           26
#  Ecuador                          24
#  Portugal                         24
#  Haiti                            24
# ...

# %%
test["workclass"] = test["workclass"].replace(" ?", None)
test["occupation"] = test["occupation"].replace(" ?", None)
test["native-country"] = test["native-country"].replace(" ?", None)

# %%
test.isnull().sum()
# Out:
# no                   0
# age                  0
# workclass         1136
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1141
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     362
# dtype: int64

# %%
test[test["workclass"].isnull()]
# Out:
#           no  age workclass  fnlwgt      education  education-num  \
# 0      29306   18      None  245274   Some-college             10
# 9      29315   36      None  205396        HS-grad              9
# 15     29321   21      None  357029   Some-college             10
# 22     29328   49      None  188141   Some-college             10
# 47     29353   72      None   94268        HS-grad              9
# ...      ...  ...       ...     ...            ...            ...
# 19468  48774   24      None  390608        HS-grad              9
# 19474  48780   30      None  108464   Some-college             10
# 19484  48790   31      None  317761      Bachelors             13
# 19499  48805   18      None   51574        HS-grad              9
# 19525  48831   22      None  244771           11th              7
#
#             marital-status occupation    relationship                 race  \
# 0            Never-married       None       Own-child                White
# ...

# %% [markdown]
# # 결측치 채우기

# %%
train["workclass"].value_counts()
# Out:
#  Private             20410
#  Self-emp-not-inc     2305
#  Local-gov            1868
#  State-gov            1201
#  Self-emp-inc          987
#  Federal-gov           854
#  Without-pay            12
#  Never-worked            5
# Name: workclass, dtype: int64

# %%
# 가장 많은 데이터수를 갖는 클래스(Private)로 결측치를 할당
# train["workclass"] = train["workclass"].fillna(" Private")

# %%
train.tail()
# Out:
#           no  age          workclass  fnlwgt education  education-num  \
# 29300  29301   20            Private  100605   HS-grad              9
# 29301  29302   21            Private  372636   HS-grad              9
# 29302  29303   18   Self-emp-not-inc  258474      10th              6
# 29303  29304   33            Private  157446      11th              7
# 29304  29305   65               None   94809   HS-grad              9
#
#        marital-status        occupation    relationship    race      sex  \
# 29300   Never-married             Sales       Own-child   Other     Male
# 29301   Never-married             Sales       Own-child   Black     Male
# 29302   Never-married   Farming-fishing       Own-child   White     Male
# 29303   Never-married      Craft-repair   Not-in-family   White     Male
# 29304         Widowed              None   Not-in-family   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  income
# ...

# %% [markdown]
# ## 편향 확인

# %%
train.skew()
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_22544\3574648760.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train.skew()
# no                 0.000000
# age                0.561713
# fnlwgt             1.451305
# education-num     -0.330375
# capital-gain      11.822983
# capital-loss       4.574764
# hours-per-week     0.190320
# income             1.215041
# dtype: float64

# %%
test.skew()
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_22544\1515727625.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   test.skew()
# no                 0.000000
# age                0.551233
# fnlwgt             1.420341
# education-num     -0.295807
# capital-gain      12.005525
# capital-loss       4.562399
# hours-per-week     0.309013
# dtype: float64

# %%
train.corr()
# Out:
#                       no       age    fnlwgt  education-num  capital-gain  \
# no              1.000000  0.001111  0.002347      -0.008466      0.003916
# age             0.001111  1.000000 -0.075753       0.035084      0.078498
# fnlwgt          0.002347 -0.075753  1.000000      -0.030600     -0.005051
# education-num  -0.008466  0.035084 -0.030600       1.000000      0.127651
# capital-gain    0.003916  0.078498 -0.005051       0.127651      1.000000
# capital-loss    0.003246  0.054413 -0.001513       0.083925     -0.031401
# hours-per-week  0.003166  0.073100 -0.010154       0.147569      0.088609
# income         -0.004080  0.238460 -0.002994       0.331798      0.221387
#
#                 capital-loss  hours-per-week    income
# no                  0.003246        0.003166 -0.004080
# age                 0.054413        0.073100  0.238460
# fnlwgt             -0.001513       -0.010154 -0.002994
# education-num       0.083925        0.147569  0.331798
# ...

# %%
train.describe()
# Out:
#                  no           age        fnlwgt  education-num  capital-gain  \
# count  29305.000000  29305.000000  2.930500e+04   29305.000000  29305.000000
# mean   14653.000000     38.659171  1.897357e+05      10.083057   1084.531786
# std     8459.769156     13.743827  1.056348e+05       2.570371   7495.715677
# min        1.000000     17.000000  1.376900e+04       1.000000      0.000000
# 25%     7327.000000     28.000000  1.176060e+05       9.000000      0.000000
# 50%    14653.000000     37.000000  1.779550e+05      10.000000      0.000000
# 75%    21979.000000     48.000000  2.377130e+05      12.000000      0.000000
# max    29305.000000     90.000000  1.490400e+06      16.000000  99999.000000
#
#        capital-loss  hours-per-week        income
# count  29305.000000    29305.000000  29305.000000
# mean      87.073571       40.440096      0.240403
# std      401.225580       12.332840      0.427335
# min        0.000000        1.000000      0.000000
# ...

# %%
train.isna()
# Out:
#           no    age  workclass  fnlwgt  education  education-num  \
# 0      False  False      False   False      False          False
# 1      False  False      False   False      False          False
# 2      False  False      False   False      False          False
# 3      False  False      False   False      False          False
# 4      False  False      False   False      False          False
# ...      ...    ...        ...     ...        ...            ...
# 29300  False  False      False   False      False          False
# 29301  False  False      False   False      False          False
# 29302  False  False      False   False      False          False
# 29303  False  False      False   False      False          False
# 29304  False  False       True   False      False          False
#
#        marital-status  occupation  relationship   race    sex  capital-gain  \
# 0               False       False         False  False  False         False
# ...

# %%
# 빈도 대체
train["workclass"] = train["workclass"].fillna(" Private")
train["occupation"] = train["occupation"].fillna(" Prof-specialty")
train["native-country"] = train["native-country"].fillna(" United-States")

# %%
train[train["workclass"].isnull()]
# Out:
# Empty DataFrame
# Columns: [no, age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, income]
# Index: []

# %%
# 빈도 대체
test["workclass"] = test["workclass"].fillna(" Private")
test["occupation"] = test["occupation"].fillna(" Prof-specialty")
test["native-country"] = test["native-country"].fillna(" United-States")

# %%
test
# Out:
#           no  age          workclass  fnlwgt      education  education-num  \
# 0      29306   18            Private  245274   Some-college             10
# 1      29307   29            Private   83003        HS-grad              9
# 2      29308   45            Private   35136      Bachelors             13
# 3      29309   42   Self-emp-not-inc   64631      Bachelors             13
# 4      29310   41            Private  195821      Doctorate             16
# ...      ...  ...                ...     ...            ...            ...
# 19532  48838   45   Self-emp-not-inc  116789        HS-grad              9
# 19533  48839   48            Private  185079        HS-grad              9
# 19534  48840   63            Private  117473   Some-college             10
# 19535  48841   18            Private  150817           11th              7
# 19536  48842   31            Private  341632     Assoc-acdm             12
#
# ...

# %%
import seaborn as sns

# %%
sns.countplot(data = train,     # 사용할 데이터 지정
              x = 'education-num',      # x축에서 범주로 사용할 컬럼 지정
              hue = 'income'  # 각 범주를 분리할 컬럼 지정
              )
# Out:
# <AxesSubplot:xlabel='education-num', ylabel='count'>

# %%
# 인코딩할 컬럼명만 선택
categorical_features = ['workclass', 'education','marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']

# %%
# 반복문으로 인코딩하기(train)
for feature_name in categorical_features :
    one_hot = pd.get_dummies(train[feature_name], prefix=feature_name)
    train = pd.concat([train,one_hot], axis=1)        # 기존 데이터 끝에 one_hot을 붙임
    train.drop(feature_name, axis=1, inplace=True)   # 기존 글자 컬럼 삭제

# %%
# 반복문으로 인코딩하기(train)
for feature_name in categorical_features :
    one_hot = pd.get_dummies(test[feature_name], prefix=feature_name)
    test = pd.concat([test,one_hot], axis=1)        # 기존 데이터 끝에 one_hot을 붙임
    test.drop(feature_name, axis=1, inplace=True)   # 기존 글자 컬럼 삭제

# %%
train.head()
# Out:
#    no  age  fnlwgt  education-num  capital-gain  capital-loss  hours-per-week  \
# 0   1   25  219199              7             0             0              40
# 1   2   39   52978             10             0          1721              55
# 2   3   35  196899             13             0             0              50
# 3   4   64  135527             11             0             0              40
# 4   5   24   60783             10             0             0              70
#
#    income  workclass_ Federal-gov  workclass_ Local-gov  ...  \
# 0       0                       0                     0  ...
# 1       0                       0                     0  ...
# 2       0                       0                     0  ...
# 3       0                       0                     0  ...
# 4       1                       0                     0  ...
#
#    native-country_ Portugal  native-country_ Puerto-Rico  \
# 0                         0                            0
# ...

# %%
train.corr()
# Out:
#                                        no       age    fnlwgt  education-num  \
# no                               1.000000  0.001111  0.002347      -0.008466
# age                              0.001111  1.000000 -0.075753       0.035084
# fnlwgt                           0.002347 -0.075753  1.000000      -0.030600
# education-num                   -0.008466  0.035084 -0.030600       1.000000
# capital-gain                     0.003916  0.078498 -0.005051       0.127651
# ...                                   ...       ...       ...            ...
# native-country_ Thailand        -0.001776  0.003635 -0.003534       0.016290
# native-country_ Trinadad&Tobago  0.005025  0.000169  0.006659      -0.008877
# native-country_ United-States   -0.005739  0.013611 -0.079893       0.130978
# native-country_ Vietnam         -0.010373 -0.015880 -0.004631      -0.003909
# native-country_ Yugoslavia      -0.003361  0.004885  0.010224       0.001211
#
# ...

# %%
train.shape, test.shape
# Out:
# ((29305, 107), (19537, 105))

# %%
set(train.columns)-set(test.columns)
# Out:
# {'income', 'native-country_ Holand-Netherlands'}

# %%
test['native-country_ Holand-Netherlands'] = 0
# test['native-country_United-States'] = 0
# test['occupation_Prof-specialty'] = 0
# test['workclass_Private'] = 0

# %%
train.sort_index(axis=1, inplace=True)
test.sort_index(axis=1, inplace=True)

# %%
train.columns
# Out:
# Index(['age', 'capital-gain', 'capital-loss', 'education-num',
#        'education_ 10th', 'education_ 11th', 'education_ 12th',
#        'education_ 1st-4th', 'education_ 5th-6th', 'education_ 7th-8th',
#        ...
#        'sex_ Female', 'sex_ Male', 'workclass_ Federal-gov',
#        'workclass_ Local-gov', 'workclass_ Never-worked', 'workclass_ Private',
#        'workclass_ Self-emp-inc', 'workclass_ Self-emp-not-inc',
#        'workclass_ State-gov', 'workclass_ Without-pay'],
#       dtype='object', length=107)

# %%
test.columns
# Out:
# Index(['age', 'capital-gain', 'capital-loss', 'education-num',
#        'education_ 10th', 'education_ 11th', 'education_ 12th',
#        'education_ 1st-4th', 'education_ 5th-6th', 'education_ 7th-8th',
#        ...
#        'sex_ Female', 'sex_ Male', 'workclass_ Federal-gov',
#        'workclass_ Local-gov', 'workclass_ Never-worked', 'workclass_ Private',
#        'workclass_ Self-emp-inc', 'workclass_ Self-emp-not-inc',
#        'workclass_ State-gov', 'workclass_ Without-pay'],
#       dtype='object', length=106)

# %%
X_train = train.drop(['income','education-num'], axis=1)
y_train = train.income
X_test = test.drop('education-num', axis=1)

# %%
X_train.shape, y_train.shape, X_test.shape
# Out:
# ((29305, 105), (29305,), (19537, 105))

# %% [markdown]
# # 학습

# %%
from sklearn.neighbors import KNeighborsClassifier     # 모델이 예측하는 결과가 분류이기에(수치라면 회귀라서 KNeighborsRegressor)
from sklearn.tree import DecisionTreeClassifier

# %%
# 모델 생성
knn_model = KNeighborsClassifier()
tree_model = DecisionTreeClassifier()

# %%
# 모델 학습
# 지도학습이므로
knn_model.fit(X_train, y_train)
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
knn_pre = knn_model.predict(X_test)

# %%
# 모델 예측
knn_pre = knn_model.predict(X_test)
tree_pre = tree_model.predict(X_test)

# %%
# 정답파일 만들기
submission = pd.read_csv('./test _submission.csv')

# %%
submission.head()
# Out:
#       no  age          workclass  fnlwgt      education  education-num  \
# 0  29306   18                  ?  245274   Some-college             10
# 1  29307   29            Private   83003        HS-grad              9
# 2  29308   45            Private   35136      Bachelors             13
# 3  29309   42   Self-emp-not-inc   64631      Bachelors             13
# 4  29310   41            Private  195821      Doctorate             16
#
#         marital-status        occupation relationship    race      sex  \
# 0        Never-married                 ?    Own-child   White     Male
# 1   Married-civ-spouse     Other-service         Wife   White   Female
# 2   Married-civ-spouse      Tech-support      Husband   Black     Male
# 3   Married-civ-spouse   Exec-managerial      Husband   White     Male
# 4   Married-civ-spouse   Exec-managerial         Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country
# ...

# %%
submission['income'] = knn_pre

# %%
# 데이터프레임을 csv파일로 저장
submission.to_csv("./knn_pre.csv", index=False)

# %%
submission['income'] = tree_pre
submission.to_csv("./tree_pre.csv", index=False)

# %% [markdown]
# ## 데이터 스케일링

# %%
from sklearn.preprocessing import StandardScaler

# %%
# 스케일러 생성 (평균과 표준편차)
std_scaler = StandardScaler()

# %%
# 기준값 생성 (평균, 표준편차)
std_scaler.fit(X_train[['fnlwgt']])
# Out:
# StandardScaler()

# %%
# 데이터 변형
scaled_fare = std_scaler.transform(X_train[['fnlwgt']])

# %%
X_train['fnlwgt'] = scaled_fare
sns.kdeplot(data=X_train, x='fnlwgt')
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Density'>

# %%
# 테스트 데이터 변형
scaled_fare = std_scaler.transform(X_test[['fnlwgt']])
X_test['fnlwgt'] = scaled_fare

# %%
sns.kdeplot(data=X_test, x='fnlwgt')
# Out:
# <AxesSubplot:xlabel='fnlwgt', ylabel='Density'>

# %%
knn_model.fit(X_train, y_train)
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
knn_pre = knn_model.predict(X_test)
tree_pre = tree_model.predict(X_test)

# %%
submission = pd.read_csv('./test _submission.csv')

# %%
submission['income'] = knn_pre
submission.to_csv("./knn_pre1.csv", index=False)

# %%
submission['income'] = tree_pre
submission.to_csv("./tree_pre1.csv", index=False)

# %%
scaled_fare = std_scaler.transform(X_test[['fnlwgt']])
X_test['fnlwgt'] = scaled_fare

# %%
knn_model2 = KNeighborsClassifier()
knn_model2.fit(X_train,y_train)
knn_pre2 = knn_model2.predict(X_test)
submission['fnlwgt'] = knn_pre2
submission.to_csv("./knn_pre3.csv", index=False)

# %% [markdown]
# ## 하이퍼 파라미터 튜닝

# %%
from sklearn.model_selection import train_test_split

# %%
X_train2,X_val,y_train2,y_val = train_test_split(X_train,y_train,
                                                 test_size=0.3,
                                                 random_state=719)

# %%
X_train2.shape, y_train2.shape
# Out:
# ((20513, 105), (20513,))

# %%
X_val.shape, y_val.shape
# Out:
# ((8792, 105), (8792,))

# %%
# 이웃의 수마다의 정확도
train_acc = []
val_acc = []

# 사용할 이웃의 범위 값들을 정의
neighbor = range(1,20)

for n in neighbor:
    knn_model = KNeighborsClassifier(n_neighbors=n)
    knn_model.fit(X_train2, y_train2)
    
    # 이웃의 수마다의 훈련데이터 정확도와 테스트데이터 정확도를 리스트에 저장
    train_acc.append(knn_model.score(X_train2,y_train2))
    val_acc.append(knn_model.score(X_val,y_val))

plt.plot(neighbor, train_acc, label="Train")
plt.plot(neighbor, val_acc, label="Val")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [82], in <cell line: 16>()
#      13     train_acc.append(knn_model.score(X_train2,y_train2))
#      14     val_acc.append(knn_model.score(X_val,y_val))
# ---> 16 plt.plot(neighbor, train_acc, label="Train")
#      17 plt.plot(neighbor, val_acc, label="Val")
#      18 plt.legend()
#
# NameError: name 'plt' is not defined
