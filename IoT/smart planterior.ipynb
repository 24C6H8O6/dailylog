# %%
pip install cx_oracle
# Out:
# Collecting cx_oracle
#   Downloading cx_Oracle-8.3.0-cp39-cp39-win_amd64.whl (213 kB)
# Installing collected packages: cx-oracle
# Successfully installed cx-oracle-8.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
C:\Users\AI\Downloads\instantclient_21_6

# %%
import cx_Oracle
import os 

LOCATION = r"C:\\Users\\AI\\Downloads\\instantclient_21_6" #로컬.
os.environ["PATH"] = LOCATION + ";" + os.environ["PATH"] #환경변수 등록
OracleConnect = cx_Oracle.connect("c##test", "test", "192.168.70.104:1522/xe")
OracleCursor = OracleConnect.cursor()

rs = OracleCursor.execute("select * from tbl_plant1")
result = rs.fetchall()
    
rs.close()
#conn.close()

# %%
result
# Out:
# [(361, '아펠란드라', '쥐꼬리망초과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (362, '아프리칸 바이올렛', '괭이밥과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (363, '안수리움', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (364, '알로카시아 아마조니카', '천남성과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (365, '알로카시아 쿠쿨라타', '천남성과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (366, '얼룩자주달개비', '닭의장풀과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (367, '에메랄드리플 페페로미아', '후추과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (368, '에크메아 파시아타', '파인애플과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (369, '엘라티올 베고니아', '베고니아과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (370, '여우꼬리풀', '대극과', 23.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (371, '엽란', '백합과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (372, '옥살리스(사랑초)', '괭이밥과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (373, '온시디움', '난초과', 23.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (374, '왜란', '백합과', 12.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (375, '왜성종려죽', '야자과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (376, '움벨라타 고무나무', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (377, '유카', '도금양과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (378, '은사철나무', '노박덩굴과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (379, '익소라', '꼭두서니과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (380, '인삼벤자민', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (381, '자금우', '자금우과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (382, '자란', '난초과', 18.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (70, '자주색만년초', '닭의장풀과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (71, '접란', '백합과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (72, '제라니움', '쥐손풀이과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (73, '좀마삭줄', '협죽도과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (74, '종려방동사니', '사초과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (75, '종려죽', '야자과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (76, '죽백나무', '나한송과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (77, '줄리아 페페로미아', '후추과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (78, '참쇠고비(섬쇠고비)', '고비과', 18.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (79, '치자나무', '꼭두서니과', 23.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (80, '칼라데아 마코야나', '마란타과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (81, '칼라데아 인시그니스', '마란타과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (82, '칼라데아 크로카타', '마란타과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (83, '칼라디움', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (84, '칼랑코에', '돌나물과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (85, '커피나무', '꼭두서니과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (86, '켄챠야자', '야자과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (87, '코르딜리네 레드에지', '백합과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (88, '크로톤', '대극과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (89, '크로톤', '대극과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (90, '크립탄서스', '파인애플과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (91, '클레마티스', '미나리아재비과', 23.0, 15.0, 5750, 2, None, 'mb_id 0001'),
#  (92, '털달개비', '닭의장풀과', 23.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (93, '털머위', '국화과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (94, '테이블야자', '야자과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (95, '톨미아', '범의귀과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (96, '틸란드시아', '파인애플과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (97, '파키라', '물밤나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (98, '파피오페딜럼', '난초과', 23.0, 85.0, 5750, 4, None, 'mb_id 0001'),
#  (99, '팔레놉시스(호접란)', '난초과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (100, '팔손이나무', '두릅나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (101, '팬더 고무나무', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (102, '팻츠헤데라', '두릅나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (103, '페페로미아 오브투시폴리아', '후추과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (104, '페페로미아 클루시폴리아', '후추과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (105, '페페로미아 푸테올라타', '후추과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (106, '포인세티아', '대극과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (107, '폴리시아스', '두릅나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (108, '푸밀라고무나무', '뽕나무과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (109, '프테리스', '고사리과', 23.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (110, '피라칸사', '장미과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (111, '피토니아 핑크스타', '쥐꼬리망초과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (112, '피토니아 화이트스타', '쥐꼬리망초과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (113, '픽투라툼 접란', '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (114, '필레아 글라우카(타라, 블루체인)', '쐐기풀과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (115, "필로덴드론 '선라이트'", '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (116, "필로덴드론 '제나두'", '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (117, '필로덴드론 고엘디', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (118, '필로덴드론 레몬라임', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (119, '필로덴드론 셀로움', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (120, '필로덴드론 옥시카르디움', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (121, '필로덴드론 콩고', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (122, '해마리아', '난초과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (123, '행운목', '백합과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (124, '헤미오니티스(하트펀)', '고사리과', 23.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (125,
#   '헤테로파낙스 프라그란스 (해피트리)',
#   '두릅나무과',
#   23.0,
#   55.0,
#   5750,
#   3,
#   None,
#   'mb_id 0001'),
#  (126, '협죽도', '협죽도과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (127, '형광스킨답서스', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (128, '호야', '박주가리과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (129, '호야 엑소티카', '박주가리과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (130, '호주매', '도금양과', 23.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (131, '홀리아페페로미아', '후추과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (132, '황금마삭줄', '협죽도과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (133, '황금죽', '백합과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (134, '후피향나무', '차나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (135, '흰꽃나도사프란', '수선화과', 23.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (136, '흰줄무늬달개비(트라데스칸티아)', '닭의장풀과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (137, '히포에스테스', '쥐꼬리망초과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (138,
#   '페페로미아 그라베올렌스',
#   '페페로미아(Peperomia)속 (후추과)',
#   10.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (139,
#   '산세베리아 ‘하니’',
#   '산세베리아(Sansevieria)속 (용설란과)',
#   2.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (140,
#   '미파',
#   '파우카리아(Faucaria)속 (석류풀과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (141, '벽어연', '에키누스(Echinus)속 (석류풀과)', 0.0, 15.0, 5750, 5, None, 'mb_id 0001'),
#  (142,
#   '입전봉',
#   '시노크라술라(Sinocrassula)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (143,
#   '사마로',
#   '시노크라술라(Sinocrassula)속 (돌나물과)',
#   3.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (144,
#   '모난데스 폴리필라',
#   '모난데스(Monanthes)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (145,
#   '야로수',
#   '하워디아(Haworthia)속 (나리과)',
#   12.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (146, '수', '하워디아(Haworthia)속 (나리과)', 12.0, 15.0, 5750, 4, None, 'mb_id 0001'),
#  (147,
#   '십이지권',
#   '하워디아(Haworthia)속 (나리과)',
#   12.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (148, '알로에', '알로에(Aloe)속 (나리과)', 5.0, 15.0, 5750, 4, None, 'mb_id 0001'),
#  (149, '불야성', '알로에(Aloe)속 (나리과)', 5.0, 15.0, 5750, 4, None, 'mb_id 0001'),
#  (150,
#   '자보',
#   '가스테리아(Gasteria)속 (나리과)',
#   -5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (151,
#   '상조',
#   '파키베리아(Pachyveria)속 (돌나물과)',
#   3.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (152,
#   '자려전',
#   '파키베리아(Pachyveria)속 (돌나물과)',
#   3.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (153,
#   '입전',
#   '파키베리아(Pachyveria)속 (돌나물과)',
#   3.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (154,
#   '일레인',
#   '파키베리아(Pachyveria)속 (돌나물과)',
#   3.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (155,
#   '홍미인',
#   '파키피툼(Pachyphytum)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   3,
#   None,
#   'mb_id 0001'),
#  (156,
#   '성미인',
#   '파키피툼(Pachyphytum)속 (돌나물과)',
#   7.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (157,
#   '군작',
#   '파키피툼(Pachyphytum)속 (돌나물과)',
#   2.0,
#   15.0,
#   5750,
#   3,
#   None,
#   'mb_id 0001'),
#  (158,
#   '신화월',
#   '크라슐라(Crassula)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (159,
#   '무을녀',
#   '크라슐라(Crassula)속 (돌나물과)',
#   10.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (160,
#   '우주목',
#   '크라슐라(Crassula)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (161,
#   '십자성',
#   '크라슐라(Crassula)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (162,
#   '남십자성',
#   '크라슐라(Crassula)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (163, '염자', '크라슐라(Crassula)속 (돌나물과)', 3.0, 15.0, 5750, 4, None, 'mb_id 0001'),
#  (164, '애성', '크라슐라(Crassula)속 (돌나물과)', 7.0, 15.0, 5750, 6, None, 'mb_id 0001'),
#  (165, '기천', '크라슐라(Crassula)속 (돌나물과)', 5.0, 15.0, 5750, 5, None, 'mb_id 0001'),
#  (166, '은전', '크라슐라(Crassula)속 (돌나물과)', 0.0, 15.0, 5750, 4, None, 'mb_id 0001'),
#  (167, '백로', '크라슐라(Crassula)속 (돌나물과)', 7.0, 15.0, 5750, 3, None, 'mb_id 0001'),
#  (168,
#   '크라슐라 ‘다비드’',
#   '크라슐라(Crassula)속 (돌나물과)',
#   7.0,
#   15.0,
#   5750,
#   3,
#   None,
#   'mb_id 0001'),
#  (169,
#   '크라슐라 ‘부다템플’',
#   '크라슐라(Crassula)속 (돌나물과)',
#   7.0,
#   15.0,
#   5750,
#   3,
#   None,
#   'mb_id 0001'),
#  (170,
#   '적귀성',
#   '크라슐라(Crassula)속 (돌나물과)',
#   7.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (171, '화제', '크라슐라(Crassula)속 (돌나물과)', 7.0, 15.0, 5750, 5, None, 'mb_id 0001'),
#  (172,
#   '복랑',
#   '코티레돈(Cotyledon)속 (돌나물과)',
#   7.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (173,
#   '백미인',
#   '코티레돈(Cotyledon)속 (돌나물과)',
#   7.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (174,
#   '웅동자',
#   '코티레돈(Cotyledon)속 (돌나물과)',
#   -1.0,
#   15.0,
#   5750,
#   3,
#   None,
#   'mb_id 0001'),
#  (175,
#   '월토이',
#   '칼랑코에(Kalanchoe)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (176,
#   '당인',
#   '칼랑코에(Kalanchoe)속 (돌나물과)',
#   -2.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (177,
#   '캐시미어바이올렛',
#   '에오니움(Aeonium)속 (돌나물과)',
#   -7.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (178, '소인제', '에오니움(Aeonium)속 (돌나물과)', 0.0, 15.0, 5750, 4, None, 'mb_id 0001'),
#  (179,
#   '유접곡',
#   '에오니움(Aeonium)속 (돌나물과)',
#   -7.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (180,
#   '흑법사(黑法師)',
#   '에오니움(Aeonium)속 (돌나물과)',
#   -2.0,
#   15.0,
#   5750,
#   4,
#   None,
#   'mb_id 0001'),
#  (181,
#   '홍용월',
#   '그랍토페탈(Graptopetalum)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (182,
#   '그랍토페탈룸 멘도자',
#   '그랍토페탈(Graptopetalum)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (183,
#   '그랍토베리아 ‘퍼플드림’',
#   '그랍토베리아(Graptoveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (184,
#   '흑괴리',
#   '그랍토베리아(Graptoveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (185,
#   '그랍토베리아 ‘실버스타’',
#   '그랍토베리아(Graptoveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (186,
#   '그랍토베리아 ‘데비’',
#   '그랍토베리아(Graptoveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (187,
#   '백모단',
#   '그랍토베리아(Graptoveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (188,
#   '연봉',
#   '그랍토베리아(Graptoveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (189,
#   '에케베리아 ‘탱고’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (190,
#   '에케베리아 ‘블루에뜨’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (191,
#   '에케베리아 ‘미니캐슬’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (192,
#   '에케베리아 톨루센시스',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (193,
#   '에케베리아 ‘데저스스타’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (194,
#   '환엽홍사',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (195,
#   '에케베리아 ‘릴리시아나’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (196,
#   '조몽',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (197,
#   '구미리',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (198,
#   '에케베리아 ‘글라우카’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (199,
#   '에케베리아 ‘톱시터비’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (200,
#   '대화금',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (201,
#   '에케베리아 푸미라',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (202,
#   '금황성',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (203,
#   '라일락',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (204,
#   '양로',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (205,
#   '샤비홍',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (206,
#   '홍매화',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (207,
#   '몰라코',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (208,
#   '에케베리아 ‘라임앤칠리’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (209,
#   '먼로',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (210,
#   '에케베리아 ‘미니벨’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (211,
#   '부용',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (212,
#   '에케베리아 ‘라즈베리아이스’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (213,
#   '에케베리아 ‘도리스테일러’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (214,
#   '정야',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   3.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (215,
#   '에케베리아 ‘펀퀸’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   3.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (216,
#   '홍화장',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (217,
#   '에케베리아 ‘치와와린제’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (218,
#   '에케베리아 ‘크리스마스’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   3.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (219,
#   '에케베리아 ‘레이디스핑거’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (220,
#   '에케베리아 ‘제이드포인트’',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   2,
#   None,
#   'mb_id 0001'),
#  (221,
#   '핑크세도이데스',
#   '에케베리아(Echeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (222,
#   '천장금',
#   '아드로미스츄(Adropmischus)속 (돌나물과)',
#   12.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (223, '녹영', '세네시오(Senecio)속 (국화과)', 7.0, 15.0, 5750, 4, None, 'mb_id 0001'),
#  (224,
#   '바위솔',
#   '바위솔(Orostachys)속 (돌나물과)',
#   0.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (225,
#   '세데베리아 ‘팡파레’',
#   '세데베리아(Sedeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   6,
#   None,
#   'mb_id 0001'),
#  (226,
#   '세데베리아 ‘레티지아’',
#   '세데베리아(Sedeveria)속 (돌나물과)',
#   5.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (227, '홍옥', '세덤(Sedum)속 (돌나물과)', 5.0, 15.0, 5750, 5, None, 'mb_id 0001'),
#  (228, '을녀심', '세덤(Sedum)속 (돌나물과)', 5.0, 15.0, 5750, 4, None, 'mb_id 0001'),
#  (229, '옥주염', '세덤(Sedum)속 (돌나물과)', 5.0, 15.0, 5750, 5, None, 'mb_id 0001'),
#  (230, '황금세덤', '세덤(Sedum)속 (돌나물과)', 5.0, 15.0, 5750, 6, None, 'mb_id 0001'),
#  (231, '환엽송록', '세덤(Sedum)속 (돌나물과)', 5.0, 15.0, 5750, 6, None, 'mb_id 0001'),
#  (232,
#   "세덤 '리틀잼'",
#   '세덤(Sedum)속 (돌나물과)',
#   4.0,
#   15.0,
#   5750,
#   5,
#   None,
#   'mb_id 0001'),
#  (233, "세덤 '라울'", '세덤(Sedum)속 (돌나물과)', 5.0, 15.0, 5750, 6, None, 'mb_id 0001'),
#  (234, '가울테리아', '진달래과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (235, '개운죽', '백합과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (236, "골드크레스트 '윌마'", '측백나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (237, '공작야자', '야자과', 23.0, 85.0, 5750, 3, None, 'mb_id 0001'),
#  (238, '관엽베고니아', '베고니아과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (239, '관음죽', '야자과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (240, '구문초', '쥐손이풀과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (241, '구즈마니아', '파인애플과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (242, '군자란', '수선화과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (243, '글레코마', '꿀풀과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (244, '금목서', '물푸레나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (245, '금사철나무', '노박덩굴과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (246, '금식나무', '층층나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (247, '금전수', '천남성과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (248, '금천죽', '백합과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (249, '기누라', '국화과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (250, '꽃베고니아', '베고니아과', 23.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (251, '나도풍란', '난초과', 23.0, 85.0, 5750, 4, None, 'mb_id 0001'),
#  (252, '나한송', '나한송과', 12.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (253, '남천', '매자나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (254, '네마탄투스', '괭이밥과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (255, '네오레겔리아', '파인애플과', 18.0, 85.0, 5750, 3, None, 'mb_id 0001'),
#  (256, '녹영', '국화과', 18.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (257, '뉴기니아봉선화', '봉선화과', 23.0, 20.0, 5750, 2, None, 'mb_id 0001'),
#  (258, '대만고무나무', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (259, '더피고사리', '고란초과', 18.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (260, '덕구리난', '백합과', 23.0, 20.0, 5750, 3, None, 'mb_id 0001'),
#  (261, '데코라고무나무', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (262, '덴파레', '난초과', 23.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (263, '도깨비고비', '면마과', 18.0, 20.0, 5750, 2, None, 'mb_id 0001'),
#  (264, '돈나무', '돈나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (265, '동백', '차나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (266, '둥근잎 아랄리아', '두릅나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (267, '듀란타', '마편초과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (268, "드라세나  '송오브자마이카'", '백합과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (269, "드라세나  '와네끼'", '백합과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (270, "드라세나 '송오브인디아'", '백합과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (271, "드라세나 '자바'", '백합과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (272, "드라세나 '콤팩타'", '백합과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (273, "드라세나 '트리컬러 레인보우'", '백합과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (274, '드라세나 드라코', '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (275, '드라세나 마지나타', '백합과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (276, '드라세나 맛상게아나', '백합과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (277, '드라세나 산데리아나', '백합과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (278, "드라세나 산데리아나 '세레스'", '백합과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (279, '드라세나 수르쿨로사', '백합과', 18.0, 20.0, 5750, 3, None, 'mb_id 0001'),
#  (280, '디지고데카', '두릅나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (281, "디펜바키아 '마리안느'", '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (282, "디펜바키아 '트로픽스노우'", '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (283, '떡갈잎 고무나무', '뽕나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (284, '러브체인', '박주가리과', 18.0, 20.0, 5750, 4, None, 'mb_id 0001'),
#  (285, '렉스베고니아', '베고니아과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (286, '루모라고사리', '고란초과', 18.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (287, '루스커스', '백합과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (288, '마란타 류코뉴라', '마란타과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (289, '마삭줄', '협죽도과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (290, '만년청', '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (291, '만데빌라', '협죽도과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (292, '멕시코소철', '소철과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (293, '멜라니 고무나무', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (294, '목베고니아', '베고니아과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (295, '몬스테라', '천남성과', 18.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (296, '무늬관음죽', '야자과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (297, '무늬마삭줄', '협죽도과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (298, '무늬벤자민고무나무', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (299, '무늬산호수', '자금우과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (300, '무늬석창포', '천남성과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (301, "무늬쉐플레라'홍콩'", '두릅나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (302, '무늬알피니아', '생강과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (303, '무늬유카', '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (304, '무늬접란', '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (305, '무늬털머위', '국화과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (306, '무늬팻츠헤데라', '두릅나무과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (307, '무늬푸밀라고무나무 ', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (308, '뮤렌베키아', '마디풀과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (309, '바위취', '범위귀과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (310, '박쥐란', '고사리과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (311, '반딧불털머위', '국화과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (312, '백량금', '자금우과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (313, '백정화', '꼭두서니과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (314, '백화등', '협죽도과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (315, '벤자민고무나무', '물밤나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (316, "벤자민고무나무 '킹'", '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (317, '벵갈고무나무', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (318, '병솔나무', '도금양과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (319, '보스톤고사리', '고란초과', 18.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (320, '봉의꼬리', '고사리과', 18.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (321, '부겐빌레아', '분꽃과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (322, '브룬펠시아', '가지과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (323, '브리세아', '파인애플과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (324, '비젯티접란', '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (325, '비타툼접란', '백합과', 23.0, 20.0, 5750, 3, None, 'mb_id 0001'),
#  (326, '산세베리아', '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (327, "산세베리아 '골든 하니'", '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (328, '산호수', '자금우과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (329, '삼색데코라고무나무', '뽕나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (330, "상록넉줄고사리 '후마타'", '고사리과', 18.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (331, '새우란', '난초과', 23.0, 55.0, 1150, 3, None, 'mb_id 0001'),
#  (332, '석창포', '천남성과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (333, '세네시오 라디칸스', '국화과', 23.0, 20.0, 5750, 3, None, 'mb_id 0001'),
#  (334, '세이프릿지 야자', '야자과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (335, '셀라기넬라', '부처손과', 23.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (336, '소철', '소철과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (337, '소피아 고무나무', '뽕나무과', 17.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (338, '솔레이롤리아', '쐐기풀과', 18.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (339, '수박페페로미아', '후추과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (340, '수박필레아', '쐐기풀과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (341, '수염 틸란드시아', '파인애플과', 23.0, 85.0, 5750, 2, None, 'mb_id 0001'),
#  (342, '숙근이베리스', '봉선화과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (343, "쉐플레라 '홍콩'", '두릅나무과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (344, '스킨답서스', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (345, '스파티필룸', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (346, '스파티필룸 (광엽)', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (347, '시서스', '포도과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (348, '시클라멘', '앵초과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (349, '심비디움', '난초과', 23.0, 85.0, 5750, 4, None, 'mb_id 0001'),
#  (350, '싱고니움', '천남성과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (351, '아글라오네마', '천남성과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (352, '아데니움', '협죽도과', 23.0, 55.0, 5750, 4, None, 'mb_id 0001'),
#  (353, '아디안텀', '고사리과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (354, '아라우카리아', '아라우카리아과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (355, '아레카야자', '야자과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (356, '아마릴리스', '백합과', 23.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (357, '아스파라거스 풀루모수스', '백합과', 23.0, 55.0, 5750, 2, None, 'mb_id 0001'),
#  (358, '아스플레니움', '고란초과', 23.0, 55.0, 5750, 1, None, 'mb_id 0001'),
#  (359, '아왜나무', '인동과', 18.0, 55.0, 5750, 3, None, 'mb_id 0001'),
#  (360, '아이비', '두릅나무과', 18.0, 55.0, 5750, 2, None, 'mb_id 0001')]

# %%
data = 23.80 59.30 894 835

# %%
print(rs)
# Out:
# <cx_Oracle.Cursor on <cx_Oracle.Connection to c##test@192.168.70.104:1522/xe>>

# %%
from flask import Flask,render_template

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('main.html')

@app.route('/cal')
def cal():
    return '계산 완료'

if __name__ == '__main__':
    app.run(host='192.168.0.4', port=5021)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://192.168.0.4:5021/ (Press CTRL+C to quit)
# 192.168.0.4 - - [21/Aug/2022 19:10:13] "GET / HTTP/1.1" 200 -
# 192.168.0.4 - - [21/Aug/2022 19:10:31] "GET /cal HTTP/1.1" 200 -

# %%
import requests
import time
import sen_all
from concurrent.futures import ThreadPoolExecutor
import RPi.GPIO as gp
gp.setmode(gp.BCM)
gp.setup(18,gp.OUT)
gp.setup(22,gp.OUT)
gp.setup(23,gp.OUT)
gp.setup(24,gp.OUT)
gp.setup(25,gp.OUT)
def get_url(url):
    return requests.get(url)
data = sen_all.data_send()
temp, hd, lux, waterA, waterD, moi = data.split(' ')
def tes(data):
    list_of_urls = [f"http://192.168.0.4:5011/test?data={data}"]
    with ThreadPoolExecutor(max_workers=10) as pool:
        response_list = list(pool.map(get_url,list_of_urls))
    for response in response_list:
        print(response)
while True:
    #tes(data)
    time.sleep(1)
    # 히터 작동
    if float(temp) >= plant_dataset_temp:
        gp.output(18,gp.HIGH)
    else:
    gp.output(18,gp.LOW)
    # 팬 작동
    if hd >= plant_dataset_hd:
        gp.output(22,gp.HIGH)
    else:
        gp.output(22,gp.LOW)
    # 급수 탱크(수위 조절)
    if waterA <= 120:
        def add_water(data1):
            data1 = 'Please add water'
            addWater = [f"http://192.168.0.4:5011/test?data={data1}"]
            with ThreadPoolExecutor(max_workers=10) as pool:
                response_list = list(pool.map(get_url,addWater))
            for response in response_list:
                print(response)
    # 배수 탱크(수위 조절)
    if waterD >= 500:
        def dump_water(data2):
            data2 = 'Please dump water'
            dumpWater = [f"http://192.168.0.4:5011/test?data={data2}"]
            with ThreadPoolExecutor(max_workers=10) as pool:
                response_list = list(pool.map(get_url,dumpWater))
            for response in response_list:
                print(response)
    # 토양 습도(물주기)
    if moi <= plant_dataset_moi:
        gp.output(23,gp.HIGH)
    else:
        gp.output(23,gp.LOW)
# Out:
#   Input In [5]
#     gp.output(18,gp.LOW)
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ### 프로젝트(스마트 플렌테리어)

# %%
from flask import Flask,render_template
import requests
import time
import sen_all
from concurrent.futures import ThreadPoolExecutor
import RPi.GPIO as gp
app = Flask(__name__)
# 1. 히터(18),팬(22),물펌프(23) 값 설정
gp.setmode(gp.BCM)
gp.setup(18,gp.OUT)
gp.setup(22,gp.OUT)
gp.setup(23,gp.OUT)
# 2. temp(온도), hd(습도), lux(조도), waterA(급수), waterD(배수), moi(토양습도) 센서값 띄어쓰기로 분리
# 아두이노에서 받은 센서값 계속 오라클db로 전달
def get_url(url):
    return requests.get(url)
data = sen_all.data_send()
temp, hd, lux, waterA, waterD, moi = data.split(' ')
def tes(data):
    list_of_urls = [f"http://192.168.0.4:5011?data={data}"]
    with ThreadPoolExecutor(max_workers=10) as pool:
        response_list = list(pool.map(get_url,list_of_urls))
    for response in response_list:
        print(response)
        
# 3. 물탱크 관련       
 # 1) 급수 탱크(수위 조절)
if int(waterA) <= 120:
    '''def add_water(data1):
        data1 = 'Please add water'
        addWater = [f"http://192.168.30.114:5099/test?data={data1}"]
        with ThreadPoolExecutor(max_workers=10) as pool:
            response_list = list(pool.map(get_url,addWater))
        for response in response_list:
            print(response)'''
            
    @app.route('/', methods=['GET','POST'])
    def add_water():
        value = 'Please add water'
        return render_template('index.html', value = value)
 # 2) 배수 탱크(수위 조절)
if int(waterD) >= 500:
    '''def dump_water(data2):
        data2 = 'Please dump water'
        dumpWater = [f"http://192.168.30.114:5099/test?data={data2}"]
        with ThreadPoolExecutor(max_workers=10) as pool:
            response_list = list(pool.map(get_url,dumpWater))
        for response in response_list:
            print(response)'''
    @app.route('/', methods=['GET','POST'])
    def dump_water():
        value = 'Please dump water'
        return render_template('index.html', value = value)
                
# 4-1. 수동 제어(html에서 각각의 토글스위치가 on/off되는 것에 <<function fan_on(){fetch('/fan/on')}>> 이런식으로 작성 필요)
@app.route('/auto/off')
def auto_off():
    gp.output(18, gp.LOW)
    gp.output(22, gp.LOW)
    gp.output(23, gp.LOW)
    time.sleep(1)
 # 1) 팬 수동제어
@app.route('/led/on')
def fan_on():
    gp.output(18, gp.HIGH)
@app.route('/led/off')
def fan_off():
    gp.output(18, gp.LOW)
 # 2) 히터 수동제어
@app.route('/heat/on')
def heat_on():
    gp.output(22, gp.HIGH)
@app.route('/heat/off')
def heat_off():
    gp.output(22, gp.LOW)
 # 3) 워터펌프 수동제어
@app.route('/pump/on')
def pump_on():
    gp.output(23, gp.HIGH)
@app.route('/pump/off')
def pump_off():
    gp.output(23, gp.LOW)

# 4-2. 자동 제어
@app.route('/auto/on')
def auto_on():
    gp.output(18, gp.LOW)
    gp.output(22, gp.LOW)
    gp.output(23, gp.LOW)
    time.sleep(1)
    
    while True:
        #tes(data)
        time.sleep(1)
        # 히터 작동
        if float(temp) <= plant_dataset_temp:
            gp.output(18,gp.HIGH)
        else:
            gp.output(18,gp.LOW)
        # 팬 작동
        if float(hd) >= plant_dataset_hd:
            gp.output(22,gp.HIGH)
        else:
            gp.output(22,gp.LOW)
        # 토양 습도(물주기)
        if int(moi) <= plant_dataset_moi:
            gp.output(23,gp.HIGH)
        else:
            gp.output(23,gp.LOW)

# %%
from flask import Flask,render_template,redirect,request
from multiprocessing import Process
import time
import sen_all
from concurrent.futures import ThreadPoolExecutor
import RPi.GPIO as gp
import pandas as pd

plant_dataset = pd.read_csv("gardenAll.csv", encoding='euc-kr')

app = Flask(__name__)
@app.route('/')
def index():
    return render_template('index.html')

# 1. 히터(18),팬(22),물펌프(23) 값 설정
gp.setmode(gp.BCM)
gp.setup(18,gp.OUT)
gp.setup(22,gp.OUT)
gp.setup(23,gp.OUT)

# 2. temp(온도), hd(습도), lux(조도), waterA(급수), waterD(배수), moi(토양습도) 센서값 띄어쓰기로 분리
# 아두이노에서 받은 센서값 오라클db로 전달
def get_url(url):
    return requests.get(url)
data = sen_all.data_send()
temp, hd, lux, waterA, waterD, moi = data.split(' ')
def tes(data):
    list_of_urls = [f"http://192.168.70.104:8088?data={data}"]
    with ThreadPoolExecutor(max_workers=10) as pool:
        response_list = list(pool.map(get_url,list_of_urls)) 
    for response in response_list:
        print(response)

# 급수 탱크(수위 조절)
if int(waterA) <= 120:
    '''def add_water(data1):
        data1 = 'Please add water'
        addWater = [f"http://192.168.70.104:8088/?data={data1}"]
        with ThreadPoolExecutor(max_workers=10) as pool:
            response_list = list(pool.map(get_url,addWater))  
        for response in response_list:
            print(response)'''
    @app.route('/', methods=['GET','POST'])
    def add_water():
        value = 'Please add water'
        return render_template('index.html', value = value)

# 배수 탱크(수위 조절)
if int(waterD) >= 500:
    '''def dump_water(data2):
        data2 = 'Please dump water'
        dumpWater = [f"http://192.168.70.104:8088/?data={data2}"]
        with ThreadPoolExecutor(max_workers=10) as pool:
            response_list = list(pool.map(get_url,dumpWater))  
        for response in response_list:
            print(response)'''
    @app.route('/', methods=['GET','POST'])
    def dump_water():
        value = 'Please dump water'
        return render_template('index.html', value = value)

# 3-1. 수동 제어(html에서 각각의 토글스위치가 on/off되는 것에 <<function fan_on(){fetch('/fan/on')}>> 이런식으로 작성 필요)
@app.route('/auto/off')
def auto_off():
    gp.output(18, gp.LOW)
    gp.output(22, gp.LOW)
    gp.output(23, gp.LOW)
    time.sleep(1)
 # 1) 히터 수동제어
@app.route('/heat/on')
def heat_on():
    gp.output(18, gp.HIGH)
@app.route('/heat/off')
def heat_off():
    gp.output(18, gp.LOW)
 # 2) 팬 수동제어
@app.route('/fan/on')
def fan_on():
    gp.output(22, gp.HIGH)
@app.route('/fan/off')
def fan_off():
    gp.output(22, gp.LOW)
 # 3) 워터펌프 수동제어
@app.route('/pump/on')
def pump_on():
    gp.output(23, gp.HIGH)
@app.route('/pump/off')
def pump_off():
    gp.output(23, gp.LOW)

# 자동제어에서는 데이터베이스에서 plant_dataset_temp, plant_dataset_hd, plant_dataset_moi값을 요청해
# 받아와서 제어
# 웹에서 보낸 값 라파에 넣기
plant
# 3-2. 자동 제어
@app.route('/auto/on')
def auto_on():
    gp.output(18, gp.LOW)
    gp.output(22, gp.LOW)
    gp.output(23, gp.LOW)
    time.sleep(1)

while True:
    #tes(data)
    time.sleep(1) 
    # 히터 작동
    if float(temp) <= float(plant_dataset_temp): 
        gp.output(18,gp.HIGH)
    else:
        gp.output(18,gp.LOW)
    # 팬 작동
    if float(hd) >= float(plant_dataset_hd):
        gp.output(22,gp.HIGH)
    else:
        gp.output(22,gp.LOW)   
    # 토양 습도(물주기)
    if int(moi) <= plant_dataset_moi:
        gp.output(23,gp.HIGH)
    else:
        gp.output(23,gp.LOW)

if __name__ == "__main__":
    app.run(host="192.168.70.157", port=5022)
